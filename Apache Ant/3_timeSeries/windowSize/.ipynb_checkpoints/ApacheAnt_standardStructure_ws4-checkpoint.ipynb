# %%
# %run auxStandardStructure.ipynb
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")
# Out:
# No GPU found

# %% [markdown]
# ## Preprocessing

# %%
all_releases_df = pd.read_csv('all_releases.csv')

# %%
X, y = generateStandardTimeSeriesStructure(all_releases_df, 4)
# Out:
# Generating a new dataframe without containing the last release...
# ... DONE!
# checking class larger than window size...
# DONE
# Setting the features...
# DONE
# X: (2650, 32) y: (2650,)

# %%
print("Declaring a dictionary to save results...")
results_dict = dict()
print("... DONE!")

print("Splitting dataset into train and test sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
print("General information:")
print("X Train set:", X_train.shape[0], "X Test set:", X_test.shape[0])
print("y Train set:", y_train.shape[0], "y Test set:", y_test.shape[0])
print("... DONE!")

print("Scaling features...")
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_test = pd.DataFrame(scaler.fit_transform(X_test))
print("... DONE!")

print("Setting stratified k-fold...")
k=10
kf = StratifiedKFold(n_splits=k, shuffle=False, random_state=42)
print("k =", k)
print("... DONE!\n")
# Out:
# Declaring a dictionary to save results...
# ... DONE!
# Splitting dataset into train and test sets...
# General information:
# X Train set: 1855 X Test set: 795
# y Train set: 1855 y Test set: 795
# ... DONE!
# Scaling features...
# ... DONE!
# Setting stratified k-fold...
# k = 10
# ... DONE!

# %%
y_test = pd.DataFrame(y_test)
y_train = pd.DataFrame(y_train)

# %% [markdown]
# ## Statistical Analysis

# %%
all_releases_df.describe()
# Out:
#        CountClassCoupled  CountDeclMethod  CountDeclMethodAll  \
# count       10767.000000     10767.000000        10767.000000
# mean            3.212966         7.791957           23.463453
# std             4.262742        10.075647           27.670783
# min             0.000000         0.000000            0.000000
# 25%             0.000000         2.000000            4.000000
# 50%             2.000000         4.000000           12.000000
# 75%             4.000000        10.000000           38.000000
# max            40.000000       125.000000          210.000000
#
#        CountClassDerived  CountLineCode  SumCyclomatic  PercentLackOfCohesion  \
# count       10767.000000   10767.000000   10767.000000           10767.000000
# mean            0.526702      79.394446      36.223553              32.550014
# std             4.996340     127.175324      29.731811              35.272832
# min             0.000000       0.000000       0.000000               0.000000
# 25%             0.000000      13.000000       8.000000               0.000000
# 50%             0.000000      37.000000      33.000000              19.000000
# 75%             0.000000      89.000000      62.000000              68.000000
# max           166.000000    1586.000000      99.000000             100.000000
#
#        MaxInheritanceTree  class_frequency   will_change  number_of_changes  \
# count        10767.000000     10767.000000  10767.000000       10767.000000
# mean             2.168478         3.288195      0.346893           5.302684
# std              1.145320         2.113989      0.476004           3.552433
# min              1.000000         1.000000      0.000000           0.000000
# 25%              1.000000         1.000000      0.000000           0.000000
# 50%              2.000000         3.000000      0.000000           6.000000
# 75%              3.000000         5.000000      1.000000           8.000000
# max              7.000000        10.000000      1.000000          10.000000
#
#             release
# count  10767.000000
# mean       7.056283
# std        2.272490
# min        1.000000
# 25%        6.000000
# 50%        7.000000
# 75%        9.000000
# max       10.000000

# %%
ax = y_train.groupby([0])[0].count().plot.bar(title="Class Distribution", figsize=(5,5))
y_train.groupby([0])[0].count()
# Out:
# 0
# False    938
# True     917
# Name: 0, dtype: int64

# %%
X_train.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col1 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col2 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col3 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col4 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col5 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col6 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col7 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col8 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col9 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col10 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col11 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col12 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col13 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col14 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col15 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col16 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col17 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col18 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col19 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col20 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col21 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col22 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col23 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col24 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col25 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col26 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col27 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col28 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col29 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col30 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row0_col31 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col0 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col2 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col3 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col4 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col5 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col6 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col8 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col9 {
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col10 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col11 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col12 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col13 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col14 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col15 {
#             background-color:  #6282ea;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col16 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col17 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col18 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col19 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col20 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col21 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col22 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col23 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col24 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col25 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col26 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_98085b56_16a6_11ea_95e7_e0d55eb0dab9row1_col27 {
#             background-color:  #

# %% [markdown]
# ## Imbalanced baseline

# %%
# %%time
LogisticRegr_(X_train, y_train, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.6919518963922294
# 2 of KFold 10
# ROC AUC score: 0.7250231267345051
# 3 of KFold 10
# ROC AUC score: 0.708950046253469
# 4 of KFold 10
# ROC AUC score: 0.7251387604070305
# 5 of KFold 10
# ROC AUC score: 0.7035152636447735
# 6 of KFold 10
# ROC AUC score: 0.7257169287696578
# 7 of KFold 10
# ROC AUC score: 0.7305735430157262
# 8 of KFold 10
# ROC AUC score: 0.7014846855272387
# 9 of KFold 10
# ROC AUC score: 0.7162944582299421
# 10 of KFold 10
# ROC AUC score: 0.7436488242939855
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7172297533268559
# Std deviation: 0.014885355244973395
#
# TEST SET:
# F1-Score(micro): 0.7358490566037735
# F1-Score(macro): 0.7348417468203245
# F1-Score(weighted): 0.7350267629029988
# F1-Score(None): [0.75118483 0.71849866]
# Accuracy: 0.7358490566037735
# Sensitivity: 0.6819338422391857
# Specificity: 0.7885572139303483
# Confusion Matrix: [0.7885572139303483, 0.68]
# ROC AUC score: 0.7352455280847671
# CPU times: user 1.08 s, sys: 668 ms, total: 1.75 s
# Wall time: 237 ms

# %%
# %%time
DecisionTree_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 14 µs, sys: 2 µs, total: 16 µs
# Wall time: 4.05 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7747456059204441
# 2 of KFold 10
# ROC AUC score: 0.6777289546716003
# 3 of KFold 10
# ROC AUC score: 0.6991211840888067
# 4 of KFold 10
# ROC AUC score: 0.7577474560592045
# 5 of KFold 10
# ROC AUC score: 0.7740518038852914
# 6 of KFold 10
# ROC AUC score: 0.7417900092506937
# 7 of KFold 10
# ROC AUC score: 0.7422525439407957
# 8 of KFold 10
# ROC AUC score: 0.7027121814355857
# 9 of KFold 10
# ROC AUC score: 0.7331324589389105
# 10 of KFold 10
# ROC AUC score: 0.7827011697979439
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7385983367989277
# Std deviation: 0.03388226863338554
#
# TEST SET:
# F1-Score(micro): 0.6276729559748427
# F1-Score(macro): 0.6239597049461155
# F1-Score(weighted): 0.6235366763479061
# F1-Score(None): [0.58659218 0.66132723]
# Accuracy: 0.6276729559748427
# Sensitivity: 0.7353689567430025
# Specificity: 0.5223880597014925
# Confusion Matrix: [0.5223880597014925, 0.74]
# ROC AUC score: 0.6288785082222474
# CPU times: user 367 ms, sys: 224 ms, total: 591 ms
# Wall time: 155 ms

# %%
# %%time
RandomForest_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7688482886216466
# 2 of KFold 10
# ROC AUC score: 0.7474560592044404
# 3 of KFold 10
# ROC AUC score: 0.7044403330249768
# 4 of KFold 10
# ROC AUC score: 0.7742830712303422
# 5 of KFold 10
# ROC AUC score: 0.7416743755781684
# 6 of KFold 10
# ROC AUC score: 0.7583256244218317
# 7 of KFold 10
# ROC AUC score: 0.7419056429232193
# 8 of KFold 10
# ROC AUC score: 0.7191956979191022
# 9 of KFold 10
# ROC AUC score: 0.7332506203473945
# 10 of KFold 10
# ROC AUC score: 0.7775611485288905
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7466940861800013
# Std deviation: 0.022607529883469406
#
# TEST SET:
# F1-Score(micro): 0.7522012578616353
# F1-Score(macro): 0.7502650986645405
# F1-Score(weighted): 0.7500161639106283
# F1-Score(None): [0.72827586 0.77225434]
# Accuracy: 0.7522012578616353
# Sensitivity: 0.8498727735368957
# Specificity: 0.6567164179104478
# Confusion Matrix: [0.6567164179104478, 0.85]
# ROC AUC score: 0.7532945957236717
# CPU times: user 1.82 s, sys: 4.39 ms, total: 1.82 s
# Wall time: 1.81 s

# %%
# %%time
NN_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.8008788159111933
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7414431082331174
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7791396854764108
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7577474560592045
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7789084181313599
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7742830712303422
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.779486586493987
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7560790273556232
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7762613730355665
# 10 of KFold 10
# ROC AUC score: 0.7764976958525347
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.772072523777934
# Std deviation: 0.015564770265294344
#
# TEST SET:
# F1-Score(micro): 0.789937106918239
# F1-Score(macro): 0.7897761190484862
# F1-Score(weighted): 0.7897102603744964
# F1-Score(None): [0.7839586  0.79559364]
# Accuracy: 0.789937106918239
# Sensitivity: 0.8269720101781171
# Specificity: 0.753731343283582
# Confusion Matrix: [0.753731343283582, 0.83]
# ROC AUC score: 0.7903516767308496
# CPU times: user 43.9 s, sys: 25.9 s, total: 1min 9s
# Wall time: 8.84 s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# ## Undersampling

# %%
print("Resampling dataset using Random UnderSampling (RUS)...")
X_RUS, y_RUS = RandomUnderSampler(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y RUS:", len(X_RUS), len(y_RUS))
# Out:
# Resampling dataset using Random UnderSampling (RUS)...
# ... DONE!
# X and Y RUS: 1834 1834

# %%
# %%time
LogisticRegr_(X_RUS, y_RUS, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7253966360491472
# 2 of KFold 10
# ROC AUC score: 0.7302405498281787
# 3 of KFold 10
# ROC AUC score: 0.7474600870827286
# 4 of KFold 10
# ROC AUC score: 0.6919791172282868
# 5 of KFold 10
# ROC AUC score: 0.6832386363636364
# 6 of KFold 10
# ROC AUC score: 0.7265523358959195
# 7 of KFold 10
# ROC AUC score: 0.7380361573909962
# 8 of KFold 10
# ROC AUC score: 0.7314736203759854
# 9 of KFold 10
# ROC AUC score: 0.7204106280193237
# 10 of KFold 10
# ROC AUC score: 0.7591787439613527
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7253966512195555
# Std deviation: 0.021836668347746203
#
# TEST SET:
# F1-Score(micro): 0.7333333333333333
# F1-Score(macro): 0.7322313734461984
# F1-Score(weighted): 0.7324258369556926
# F1-Score(None): [0.74940898 0.71505376]
# Accuracy: 0.7333333333333333
# Sensitivity: 0.6768447837150128
# Specificity: 0.7885572139303483
# Confusion Matrix: [0.7885572139303483, 0.68]
# ROC AUC score: 0.7327009988226806
# CPU times: user 971 ms, sys: 538 ms, total: 1.51 s
# Wall time: 192 ms

# %%
# %%time
DecisionTree_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 13 µs, sys: 5 µs, total: 18 µs
# Wall time: 4.53 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7107837289753072
# 2 of KFold 10
# ROC AUC score: 0.6781016708140775
# 3 of KFold 10
# ROC AUC score: 0.7427431059506532
# 4 of KFold 10
# ROC AUC score: 0.7736117702895112
# 5 of KFold 10
# ROC AUC score: 0.7400568181818182
# 6 of KFold 10
# ROC AUC score: 0.6746303962152572
# 7 of KFold 10
# ROC AUC score: 0.7600141793690182
# 8 of KFold 10
# ROC AUC score: 0.7336567616737417
# 9 of KFold 10
# ROC AUC score: 0.6864734299516908
# 10 of KFold 10
# ROC AUC score: 0.714975845410628
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7215047706831703
# Std deviation: 0.03256812658971295
#
# TEST SET:
# F1-Score(micro): 0.6477987421383647
# F1-Score(macro): 0.6470341993099249
# F1-Score(weighted): 0.6468482294327368
# F1-Score(None): [0.63060686 0.66346154]
# Accuracy: 0.6477987421383647
# Sensitivity: 0.7022900763358778
# Specificity: 0.5945273631840796
# Confusion Matrix: [0.5945273631840796, 0.7]
# ROC AUC score: 0.6484087197599787
# CPU times: user 409 ms, sys: 152 ms, total: 561 ms
# Wall time: 184 ms

# %%
# %%time
RandomForest_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 3.81 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7628533937731122
# 2 of KFold 10
# ROC AUC score: 0.7831496622822609
# 3 of KFold 10
# ROC AUC score: 0.7576197387518142
# 4 of KFold 10
# ROC AUC score: 0.7495253915519696
# 5 of KFold 10
# ROC AUC score: 0.7178030303030304
# 6 of KFold 10
# ROC AUC score: 0.7350088704908337
# 7 of KFold 10
# ROC AUC score: 0.793217535153019
# 8 of KFold 10
# ROC AUC score: 0.7600970285021225
# 9 of KFold 10
# ROC AUC score: 0.779951690821256
# 10 of KFold 10
# ROC AUC score: 0.7804347826086957
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7619661124238114
# Std deviation: 0.022237313177945958
#
# TEST SET:
# F1-Score(micro): 0.7446540880503144
# F1-Score(macro): 0.7422989896989856
# F1-Score(weighted): 0.7420200964731704
# F1-Score(None): [0.71766342 0.76693456]
# Accuracy: 0.7446540880503144
# Sensitivity: 0.8498727735368957
# Specificity: 0.6417910447761194
# Confusion Matrix: [0.6417910447761194, 0.85]
# ROC AUC score: 0.7458319091565077
# CPU times: user 1.93 s, sys: 10.1 ms, total: 1.94 s
# Wall time: 1.93 s

# %%
# %%time
NN_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.777704878921627
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7762175613224316
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7559264634736332
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7400332225913621
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7447916666666666
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7535777646363098
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7711213517665131
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7697392359005458
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7747584541062802
# 10 of KFold 10
# ROC AUC score: 0.7867149758454106
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7650585575230779
# Std deviation: 0.014691580866484779
#
# TEST SET:
# F1-Score(micro): 0.7811320754716982
# F1-Score(macro): 0.7807543078854273
# F1-Score(weighted): 0.7806512803618991
# F1-Score(None): [0.77165354 0.78985507]
# Accuracy: 0.7811320754716982
# Sensitivity: 0.8320610687022901
# Specificity: 0.7313432835820896
# Confusion Matrix: [0.7313432835820896, 0.83]
# ROC AUC score: 0.7817021761421898
# CPU times: user 45.4 s, sys: 25.2 s, total: 1min 10s
# Wall time: 8.88 s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
print("Resampling dataset using Edited Nearest Neighbour (ENN)...")
X_ENN, y_ENN = EditedNearestNeighbours(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y ENN:", len(X_ENN), len(y_ENN))
# Out:
# Resampling dataset using Edited Nearest Neighbour (ENN)...
# ... DONE!
# X and Y ENN: 1352 1352

# %%
# %%time
LogisticRegr_(X_ENN, y_ENN, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.6739610963748894
# 2 of KFold 10
# ROC AUC score: 0.7231235128704305
# 3 of KFold 10
# ROC AUC score: 0.699672131147541
# 4 of KFold 10
# ROC AUC score: 0.7218256543370105
# 5 of KFold 10
# ROC AUC score: 0.6848299912816042
# 6 of KFold 10
# ROC AUC score: 0.7250000000000001
# 7 of KFold 10
# ROC AUC score: 0.7351572884359769
# 8 of KFold 10
# ROC AUC score: 0.7300925925925925
# 9 of KFold 10
# ROC AUC score: 0.6807040998217468
# 10 of KFold 10
# ROC AUC score: 0.6868279569892474
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7061194323851039
# Std deviation: 0.022039229142435817
#
# TEST SET:
# F1-Score(micro): 0.740880503144654
# F1-Score(macro): 0.7393459217194225
# F1-Score(weighted): 0.7395723353723256
# F1-Score(None): [0.75934579 0.71934605]
# Accuracy: 0.740880503144654
# Sensitivity: 0.6717557251908397
# Specificity: 0.8084577114427861
# Confusion Matrix: [0.8084577114427861, 0.67]
# ROC AUC score: 0.7401067183168129
# CPU times: user 774 ms, sys: 473 ms, total: 1.25 s
# Wall time: 160 ms

# %%
# %%time
DecisionTree_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 11 µs, sys: 6 µs, total: 17 µs
# Wall time: 4.77 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.6801503094606544
# 2 of KFold 10
# ROC AUC score: 0.735885788449059
# 3 of KFold 10
# ROC AUC score: 0.7139890710382514
# 4 of KFold 10
# ROC AUC score: 0.7587064676616915
# 5 of KFold 10
# ROC AUC score: 0.7007410636442895
# 6 of KFold 10
# ROC AUC score: 0.7533333333333333
# 7 of KFold 10
# ROC AUC score: 0.7250775365529465
# 8 of KFold 10
# ROC AUC score: 0.6925925925925925
# 9 of KFold 10
# ROC AUC score: 0.7105614973262032
# 10 of KFold 10
# ROC AUC score: 0.7226702508960572
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7193707910955078
# Std deviation: 0.023928852144600266
#
# TEST SET:
# F1-Score(micro): 0.5974842767295597
# F1-Score(macro): 0.5858943639962497
# F1-Score(weighted): 0.5851100841872287
# F1-Score(None): [0.51661631 0.65517241]
# Accuracy: 0.5974842767295597
# Sensitivity: 0.7735368956743003
# Specificity: 0.4253731343283582
# Confusion Matrix: [0.4253731343283582, 0.77]
# ROC AUC score: 0.5994550150013292
# CPU times: user 378 ms, sys: 197 ms, total: 574 ms
# Wall time: 144 ms

# %%
# %%time
RandomForest_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 4.29 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7230327144120249
# 2 of KFold 10
# ROC AUC score: 0.7804455980964742
# 3 of KFold 10
# ROC AUC score: 0.7565027322404372
# 4 of KFold 10
# ROC AUC score: 0.7648712956954359
# 5 of KFold 10
# ROC AUC score: 0.716870095902354
# 6 of KFold 10
# ROC AUC score: 0.75
# 7 of KFold 10
# ROC AUC score: 0.7853345148427116
# 8 of KFold 10
# ROC AUC score: 0.763425925925926
# 9 of KFold 10
# ROC AUC score: 0.7843137254901962
# 10 of KFold 10
# ROC AUC score: 0.732078853046595
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7556875455652154
# Std deviation: 0.023704643825467792
#
# TEST SET:
# F1-Score(micro): 0.742138364779874
# F1-Score(macro): 0.7398846698342827
# F1-Score(weighted): 0.7396105718003595
# F1-Score(None): [0.71567268 0.76409666]
# Accuracy: 0.7421383647798742
# Sensitivity: 0.8447837150127226
# Specificity: 0.6417910447761194
# Confusion Matrix: [0.6417910447761194, 0.84]
# ROC AUC score: 0.7432873798944211
# CPU times: user 1.55 s, sys: 6.09 ms, total: 1.56 s
# Wall time: 1.55 s

# %%
# %%time
NN_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1 µs, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7082228116710875
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7885572139303482
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7488524590163935
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7663854639844256
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7521795989537925
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.765
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7781346920691183
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7391203703703704
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7542335115864528
# 10 of KFold 10
# ROC AUC score: 0.7862903225806451
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7586976444162633
# Std deviation: 0.02284707931175834
#
# TEST SET:
# F1-Score(micro): 0.7710691823899372
# F1-Score(macro): 0.7710514323328734
# F1-Score(weighted): 0.7710286108309343
# F1-Score(None): [0.76903553 0.77306733]
# Accuracy: 0.7710691823899372
# Sensitivity: 0.7888040712468194
# Specificity: 0.753731343283582
# Confusion Matrix: [0.753731343283582, 0.79]
# ROC AUC score: 0.7712677072652008
# CPU times: user 34.8 s, sys: 19.3 s, total: 54 s
# Wall time: 6.8 s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
print("Resampling dataset using Tomek's Link (TL)...")
X_TL, y_TL = TomekLinks(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y TL:", len(X_TL), len(y_TL))
# Out:
# Resampling dataset using Tomek's Link (TL)...
# ... DONE!
# X and Y TL: 1711 1711

# %%
# %%time
LogisticRegr_(X_TL, y_TL, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7067099567099567
# 2 of KFold 10
# ROC AUC score: 0.7194264069264069
# 3 of KFold 10
# ROC AUC score: 0.6872282608695652
# 4 of KFold 10
# ROC AUC score: 0.7309048975715642
# 5 of KFold 10
# ROC AUC score: 0.6913335158817087
# 6 of KFold 10
# ROC AUC score: 0.7202658262537681
# 7 of KFold 10
# ROC AUC score: 0.7427157001414427
# 8 of KFold 10
# ROC AUC score: 0.6928145373838257
# 9 of KFold 10
# ROC AUC score: 0.7052631578947369
# 10 of KFold 10
# ROC AUC score: 0.7375
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7134162259632975
# Std deviation: 0.018806148015448422
#
# TEST SET:
# F1-Score(micro): 0.7396226415094339
# F1-Score(macro): 0.7384157594311955
# F1-Score(weighted): 0.7386169064442353
# F1-Score(None): [0.75618375 0.72064777]
# Accuracy: 0.7396226415094339
# Sensitivity: 0.6793893129770993
# Specificity: 0.7985074626865671
# Confusion Matrix: [0.7985074626865671, 0.68]
# ROC AUC score: 0.7389483878318333
# CPU times: user 879 ms, sys: 513 ms, total: 1.39 s
# Wall time: 183 ms

# %%
# %%time
DecisionTree_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 12 µs, sys: 6 µs, total: 18 µs
# Wall time: 4.77 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7210497835497836
# 2 of KFold 10
# ROC AUC score: 0.6688311688311689
# 3 of KFold 10
# ROC AUC score: 0.6885869565217392
# 4 of KFold 10
# ROC AUC score: 0.7446750780084114
# 5 of KFold 10
# ROC AUC score: 0.7552026286966046
# 6 of KFold 10
# ROC AUC score: 0.7217045765963278
# 7 of KFold 10
# ROC AUC score: 0.7613861386138614
# 8 of KFold 10
# ROC AUC score: 0.7450409210708836
# 9 of KFold 10
# ROC AUC score: 0.7105263157894737
# 10 of KFold 10
# ROC AUC score: 0.7333333333333333
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7250336901011587
# Std deviation: 0.027948397198936607
#
# TEST SET:
# F1-Score(micro): 0.6553459119496855
# F1-Score(macro): 0.6519086457947151
# F1-Score(weighted): 0.6515170585112373
# F1-Score(None): [0.61731844 0.68649886]
# Accuracy: 0.6553459119496855
# Sensitivity: 0.7633587786259542
# Specificity: 0.5497512437810945
# Confusion Matrix: [0.5497512437810945, 0.76]
# ROC AUC score: 0.6565550112035243
# CPU times: user 425 ms, sys: 168 ms, total: 593 ms
# Wall time: 179 ms

# %%
# %%time
RandomForest_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7564935064935066
# 2 of KFold 10
# ROC AUC score: 0.7332251082251082
# 3 of KFold 10
# ROC AUC score: 0.7258152173913043
# 4 of KFold 10
# ROC AUC score: 0.7906661239994572
# 5 of KFold 10
# ROC AUC score: 0.7484939759036143
# 6 of KFold 10
# ROC AUC score: 0.7619895861879967
# 7 of KFold 10
# ROC AUC score: 0.7806223479490806
# 8 of KFold 10
# ROC AUC score: 0.7130669995838534
# 9 of KFold 10
# ROC AUC score: 0.732280701754386
# 10 of KFold 10
# ROC AUC score: 0.7895833333333333
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.753223690082164
# Std deviation: 0.02605165062225031
#
# TEST SET:
# F1-Score(micro): 0.7484276729559748
# F1-Score(macro): 0.7464050119301291
# F1-Score(weighted): 0.7461486182789654
# F1-Score(None): [0.72375691 0.76905312]
# Accuracy: 0.7484276729559748
# Sensitivity: 0.8473282442748091
# Specificity: 0.6517412935323383
# Confusion Matrix: [0.6517412935323383, 0.85]
# ROC AUC score: 0.7495347689035737
# CPU times: user 1.87 s, sys: 901 µs, total: 1.88 s
# Wall time: 1.87 s

# %%
# %%time
NN_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7800324675324676
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7086038961038961
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7983695652173912
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7707231040564375
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7502053669222346
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7615100027404769
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7949080622347948
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7540574282147315
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.78
# 10 of KFold 10
# ROC AUC score: 0.7625000000000001
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7660909893022432
# Std deviation: 0.024530426318616225
#
# TEST SET:
# F1-Score(micro): 0.7773584905660378
# F1-Score(macro): 0.7765438980119768
# F1-Score(weighted): 0.7763911619080903
# F1-Score(None): [0.76305221 0.79003559]
# Accuracy: 0.7773584905660378
# Sensitivity: 0.8473282442748091
# Specificity: 0.7089552238805971
# Confusion Matrix: [0.7089552238805971, 0.85]
# ROC AUC score: 0.7781417340777029
# CPU times: user 42.6 s, sys: 23.6 s, total: 1min 6s
# Wall time: 8.35 s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %% [markdown]
# ## Oversampling

# %%
print("Resampling dataset using Random OverSampling (ROS)...")
ros = RandomOverSampler(random_state=42)
X_ROS, y_ROS = ros.fit_resample(X_train, y_train)
print("X and Y ROS:", len(X_ROS), len(y_ROS))
# Out:
# Resampling dataset using Random OverSampling (ROS)...
# X and Y ROS: 1876 1876
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# %%time
LogisticRegr_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 14 µs, sys: 7 µs, total: 21 µs
# Wall time: 5.25 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7021276595744681
# 2 of KFold 10
# ROC AUC score: 0.723404255319149
# 3 of KFold 10
# ROC AUC score: 0.7021276595744682
# 4 of KFold 10
# ROC AUC score: 0.7234042553191489
# 5 of KFold 10
# ROC AUC score: 0.7180851063829787
# 6 of KFold 10
# ROC AUC score: 0.7287234042553191
# 7 of KFold 10
# ROC AUC score: 0.7234042553191489
# 8 of KFold 10
# ROC AUC score: 0.6914893617021277
# 9 of KFold 10
# ROC AUC score: 0.7473118279569891
# 10 of KFold 10
# ROC AUC score: 0.7311827956989246
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7191260581102723
# Std deviation: 0.015587117067162364
#
# TEST SET:
# F1-Score(micro): 0.7371069182389935
# F1-Score(macro): 0.7358883754643472
# F1-Score(weighted): 0.7360914659267882
# F1-Score(None): [0.75382803 0.71794872]
# Accuracy: 0.7371069182389937
# Sensitivity: 0.6768447837150128
# Specificity: 0.7960199004975125
# Confusion Matrix: [0.7960199004975125, 0.68]
# ROC AUC score: 0.7364323421062626
# CPU times: user 979 ms, sys: 439 ms, total: 1.42 s
# Wall time: 182 ms

# %%
# %%time
DecisionTree_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 10 µs, sys: 5 µs, total: 15 µs
# Wall time: 5.01 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7074468085106382
# 2 of KFold 10
# ROC AUC score: 0.7074468085106382
# 3 of KFold 10
# ROC AUC score: 0.675531914893617
# 4 of KFold 10
# ROC AUC score: 0.7287234042553191
# 5 of KFold 10
# ROC AUC score: 0.7021276595744681
# 6 of KFold 10
# ROC AUC score: 0.7446808510638298
# 7 of KFold 10
# ROC AUC score: 0.75
# 8 of KFold 10
# ROC AUC score: 0.7021276595744681
# 9 of KFold 10
# ROC AUC score: 0.7365591397849462
# 10 of KFold 10
# ROC AUC score: 0.7258064516129032
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7180450697780827
# Std deviation: 0.0218777548912115
#
# TEST SET:
# F1-Score(micro): 0.6352201257861635
# F1-Score(macro): 0.6282315075208339
# F1-Score(weighted): 0.6276544656457149
# F1-Score(None): [0.57725948 0.67920354]
# Accuracy: 0.6352201257861635
# Sensitivity: 0.7811704834605598
# Specificity: 0.4925373134328358
# Confusion Matrix: [0.4925373134328358, 0.78]
# ROC AUC score: 0.6368538984466978
# CPU times: user 416 ms, sys: 164 ms, total: 580 ms
# Wall time: 168 ms

# %%
# %%time
RandomForest_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7659574468085106
# 2 of KFold 10
# ROC AUC score: 0.7446808510638298
# 3 of KFold 10
# ROC AUC score: 0.7340425531914894
# 4 of KFold 10
# ROC AUC score: 0.7712765957446809
# 5 of KFold 10
# ROC AUC score: 0.7340425531914894
# 6 of KFold 10
# ROC AUC score: 0.7712765957446809
# 7 of KFold 10
# ROC AUC score: 0.7287234042553192
# 8 of KFold 10
# ROC AUC score: 0.6914893617021276
# 9 of KFold 10
# ROC AUC score: 0.7903225806451613
# 10 of KFold 10
# ROC AUC score: 0.7903225806451614
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.752213452299245
# Std deviation: 0.02962535460340924
#
# TEST SET:
# F1-Score(micro): 0.7559748427672957
# F1-Score(macro): 0.7536639748536965
# F1-Score(weighted): 0.75339387340925
# F1-Score(None): [0.72980501 0.77752294]
# Accuracy: 0.7559748427672957
# Sensitivity: 0.8625954198473282
# Specificity: 0.6517412935323383
# Confusion Matrix: [0.6517412935323383, 0.86]
# ROC AUC score: 0.7571683566898333
# CPU times: user 1.97 s, sys: 2.09 ms, total: 1.98 s
# Wall time: 1.97 s

# %%
# %%time
NN_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7872340425531915
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7340425531914894
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7872340425531916
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7606382978723404
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.776595744680851
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7606382978723404
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7712765957446809
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7553191489361702
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7956989247311828
# 10 of KFold 10
# ROC AUC score: 0.7580645161290323
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7686742164264471
# Std deviation: 0.017630144012951574
#
# TEST SET:
# F1-Score(micro): 0.7874213836477987
# F1-Score(macro): 0.7870318560588647
# F1-Score(weighted): 0.786928745814735
# F1-Score(None): [0.77792378 0.79613993]
# Accuracy: 0.7874213836477988
# Sensitivity: 0.8396946564885496
# Specificity: 0.736318407960199
# Confusion Matrix: [0.736318407960199, 0.84]
# ROC AUC score: 0.7880065322243742
# CPU times: user 46.9 s, sys: 26.7 s, total: 1min 13s
# Wall time: 9.25 s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
print("Resampling dataset using SMOTE (SMO)...")
sm = SMOTE(random_state=42)
X_SMO, y_SMO = sm.fit_resample(X_train, y_train)
print("X and Y SMO:", len(X_SMO), len(y_SMO))
# Out:
# Resampling dataset using SMOTE (SMO)...
# X and Y SMO: 1876 1876
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# %%time
LogisticRegr_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 14 µs, sys: 7 µs, total: 21 µs
# Wall time: 4.77 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7021276595744681
# 2 of KFold 10
# ROC AUC score: 0.723404255319149
# 3 of KFold 10
# ROC AUC score: 0.7021276595744681
# 4 of KFold 10
# ROC AUC score: 0.7287234042553191
# 5 of KFold 10
# ROC AUC score: 0.7127659574468085
# 6 of KFold 10
# ROC AUC score: 0.7340425531914894
# 7 of KFold 10
# ROC AUC score: 0.7180851063829788
# 8 of KFold 10
# ROC AUC score: 0.696808510638298
# 9 of KFold 10
# ROC AUC score: 0.7473118279569891
# 10 of KFold 10
# ROC AUC score: 0.7311827956989246
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7196579730038893
# Std deviation: 0.015451166784948294
#
# TEST SET:
# F1-Score(micro): 0.7371069182389935
# F1-Score(macro): 0.7358883754643472
# F1-Score(weighted): 0.7360914659267882
# F1-Score(None): [0.75382803 0.71794872]
# Accuracy: 0.7371069182389937
# Sensitivity: 0.6768447837150128
# Specificity: 0.7960199004975125
# Confusion Matrix: [0.7960199004975125, 0.68]
# ROC AUC score: 0.7364323421062626
# CPU times: user 846 ms, sys: 593 ms, total: 1.44 s
# Wall time: 184 ms

# %%
# %%time
DecisionTree_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 13 µs, sys: 7 µs, total: 20 µs
# Wall time: 4.77 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7340425531914894
# 2 of KFold 10
# ROC AUC score: 0.7127659574468085
# 3 of KFold 10
# ROC AUC score: 0.6542553191489362
# 4 of KFold 10
# ROC AUC score: 0.723404255319149
# 5 of KFold 10
# ROC AUC score: 0.7393617021276596
# 6 of KFold 10
# ROC AUC score: 0.7287234042553191
# 7 of KFold 10
# ROC AUC score: 0.723404255319149
# 8 of KFold 10
# ROC AUC score: 0.6755319148936171
# 9 of KFold 10
# ROC AUC score: 0.6881720430107527
# 10 of KFold 10
# ROC AUC score: 0.7150537634408602
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.709471516815374
# Std deviation: 0.026367487641393947
#
# TEST SET:
# F1-Score(micro): 0.6352201257861635
# F1-Score(macro): 0.6282315075208339
# F1-Score(weighted): 0.6276544656457149
# F1-Score(None): [0.57725948 0.67920354]
# Accuracy: 0.6352201257861635
# Sensitivity: 0.7811704834605598
# Specificity: 0.4925373134328358
# Confusion Matrix: [0.4925373134328358, 0.78]
# ROC AUC score: 0.6368538984466978
# CPU times: user 393 ms, sys: 196 ms, total: 589 ms
# Wall time: 184 ms

# %%
# %%time
RandomForest_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 4.53 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7606382978723405
# 2 of KFold 10
# ROC AUC score: 0.7446808510638299
# 3 of KFold 10
# ROC AUC score: 0.7180851063829787
# 4 of KFold 10
# ROC AUC score: 0.7606382978723405
# 5 of KFold 10
# ROC AUC score: 0.7340425531914894
# 6 of KFold 10
# ROC AUC score: 0.7819148936170213
# 7 of KFold 10
# ROC AUC score: 0.7393617021276596
# 8 of KFold 10
# ROC AUC score: 0.7074468085106383
# 9 of KFold 10
# ROC AUC score: 0.8010752688172043
# 10 of KFold 10
# ROC AUC score: 0.7849462365591398
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7532830016014642
# Std deviation: 0.028622526291821715
#
# TEST SET:
# F1-Score(micro): 0.7559748427672957
# F1-Score(macro): 0.7536639748536965
# F1-Score(weighted): 0.75339387340925
# F1-Score(None): [0.72980501 0.77752294]
# Accuracy: 0.7559748427672957
# Sensitivity: 0.8625954198473282
# Specificity: 0.6517412935323383
# Confusion Matrix: [0.6517412935323383, 0.86]
# ROC AUC score: 0.7571683566898333
# CPU times: user 2.04 s, sys: 4.5 ms, total: 2.04 s
# Wall time: 2.03 s

# %%
# %%time
NN_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 0 ns, sys: 2 µs, total: 2 µs
# Wall time: 3.58 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7925531914893617
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7287234042553192
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7819148936170214
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7606382978723404
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7553191489361702
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7819148936170213
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7712765957446809
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7446808510638299
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7956989247311829
# 10 of KFold 10
# ROC AUC score: 0.7688172043010753
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7681537405628003
# Std deviation: 0.020174087428129366
#
# TEST SET:
# F1-Score(micro): 0.7874213836477987
# F1-Score(macro): 0.7870318560588647
# F1-Score(weighted): 0.786928745814735
# F1-Score(None): [0.77792378 0.79613993]
# Accuracy: 0.7874213836477988
# Sensitivity: 0.8396946564885496
# Specificity: 0.736318407960199
# Confusion Matrix: [0.736318407960199, 0.84]
# ROC AUC score: 0.7880065322243742
# CPU times: user 47 s, sys: 25.9 s, total: 1min 12s
# Wall time: 9.18 s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
print("Resampling dataset using ADASYN (ADA)...")
ada = ADASYN(random_state=42)
X_ADA, y_ADA = ada.fit_resample(X_train, y_train)
print("X and Y ADA:", len(X_ADA), len(y_ADA))
# Out:
# Resampling dataset using ADASYN (ADA)...
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-093264751b61> in <module>()
#       1 print("Resampling dataset using ADASYN (ADA)...")
#       2 ada = ADASYN(random_state=42)
# ----> 3 X_ADA, y_ADA = ada.fit_resample(X_train, y_train)
#       4 print("X and Y ADA:", len(X_ADA), len(y_ADA))
#
# /usr/local/lib/python3.6/dist-packages/imblearn/base.py in fit_resample(self, X, y)
#      82             self.sampling_strategy, y, self._sampling_type)
#      83
# ---> 84         output = self._fit_resample(X, y)
#      85
#      86         if binarize_y:
#
# /usr/local/lib/python3.6/dist-packages/imblearn/over_sampling/_adasyn.py in _fit_resample(self, X, y)
#     129             n_samples_generate = np.rint(ratio_nn * n_samples).astype(int)
#     130             if not np.sum(n_samples_generate):
# --> 131                 raise ValueError("No samples will be generated with the"
#     132                                  " provided ratio settings.")
#     133
#
# ValueError: No samples will be generated with the provided ratio settings.

# %%
# %%time
LogisticRegr_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-fbba8c095a8a> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'LogisticRegr_NoIloc(X_ADA, y_ADA, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# NameError: name 'X_ADA' is not defined

# %%
# %%time
DecisionTree_NoIloc(X_ADA, y_ADA, X_test, y_test)

# %%
# %%time
RandomForest_NoIloc(X_ADA, y_ADA, X_test, y_test)

# %%
# %%time
NN_NoIloc(X_ADA, y_ADA, X_test, y_test)
