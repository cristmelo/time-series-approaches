# %%
# %run auxStandardStructure.ipynb
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
import os

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

if tf.test.gpu_device_name():
    print('GPU found')
else:
    print("No GPU found")
# Out:
# No GPU found

# %% [markdown]
# ## Preprocessing

# %%
all_releases_df = pd.read_csv('all_releases.csv')

# %%
X, y = generateStandardTimeSeriesStructure(all_releases_df, 4)
# Out:
# Generating a new dataframe without containing the last release...
# ... DONE!
# checking class larger than window size...
# DONE
# Setting the features...
# DONE
# X: (103384, 32) y: (103384,)

# %%
print("Declaring a dictionary to save results...")
results_dict = dict()
print("... DONE!")

print("Splitting dataset into train and test sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
print("General information:")
print("X Train set:", X_train.shape[0], "X Test set:", X_test.shape[0])
print("y Train set:", y_train.shape[0], "y Test set:", y_test.shape[0])
print("... DONE!")

print("Scaling features...")
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_test = pd.DataFrame(scaler.fit_transform(X_test))
print("... DONE!")

print("Setting stratified k-fold...")
k=10
kf = StratifiedKFold(n_splits=k, shuffle=False, random_state=42)
print("k =", k)
print("... DONE!\n")
# Out:
# Declaring a dictionary to save results...
# ... DONE!
# Splitting dataset into train and test sets...
# General information:
# X Train set: 72368 X Test set: 31016
# y Train set: 72368 y Test set: 31016
# ... DONE!
# Scaling features...
# ... DONE!
# Setting stratified k-fold...
# k = 10
# ... DONE!

# %%
y_test = pd.DataFrame(y_test)
y_train = pd.DataFrame(y_train)

# %% [markdown]
# ## Statistical Analysis

# %%
all_releases_df.describe()
# Out:
#        CountClassCoupled  CountDeclMethod  CountDeclMethodAll  \
# count      130773.000000    130773.000000       130773.000000
# mean            5.747073         6.513707           10.989669
# std             8.658830        12.084357           17.917928
# min             0.000000         0.000000            0.000000
# 25%             1.000000         1.000000            2.000000
# 50%             3.000000         3.000000            4.000000
# 75%             7.000000         6.000000           13.000000
# max           145.000000       294.000000          294.000000
#
#        CountClassDerived  CountLineCode  SumCyclomatic  PercentLackOfCohesion  \
# count      130773.000000  130773.000000  130773.000000          130773.000000
# mean            0.273352     103.106062      13.787349              20.578522
# std             2.303381     754.576185      31.166179              30.626505
# min             0.000000       0.000000       0.000000               0.000000
# 25%             0.000000      12.000000       2.000000               0.000000
# 50%             0.000000      32.000000       5.000000               0.000000
# 75%             0.000000      82.000000      13.000000              45.000000
# max           116.000000   45517.000000     843.000000             100.000000
#
#        MaxInheritanceTree  class_frequency    will_change  number_of_changes  \
# count       130773.000000    130773.000000  130773.000000      130773.000000
# mean             1.651251        11.395915       0.174707          27.325105
# std              0.740645        10.388216       0.379718          15.532635
# min              1.000000         1.000000       0.000000           0.000000
# 25%              1.000000         3.000000       0.000000          17.000000
# 50%              2.000000         8.000000       0.000000          31.000000
# 75%              2.000000        18.000000       0.000000          40.000000
# max              6.000000        49.000000       1.000000          49.000000
#
#              release
# count  130773.000000
# mean       32.741315
# std        11.367734
# min         1.000000
# 25%        25.000000
# 50%        35.000000
# 75%        42.000000
# max        49.000000

# %%
ax = y_train.groupby([0])[0].count().plot.bar(title="Class Distribution", figsize=(5,5))
y_train.groupby([0])[0].count()
# Out:
# 0
# False    58500
# True     13868
# Name: 0, dtype: int64

# %%
X_train.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col1 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col2 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col3 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col4 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col6 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col7 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col8 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col9 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col10 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col11 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col12 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col14 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col15 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col16 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col17 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col18 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col19 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col20 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col22 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col23 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col24 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col25 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col26 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col27 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col28 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col30 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row0_col31 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col2 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col3 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col6 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col7 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col8 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col9 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col10 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col11 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col12 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col14 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col15 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col16 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col17 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col18 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col19 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col20 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col21 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col22 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col23 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col24 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col25 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col26 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_1f9391cc_175f_11ea_95e7_e0d55eb0dab9row1_col27 {
#             background-color:  #

# %% [markdown]
# ## Imbalanced baseline

# %%
# %%time
LogisticRegr_(X_train, y_train, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7070646232722657
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.71240511711312
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7073141318346798
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7027463196100543
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7025981180559407
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6968668157925549
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.711788216589947
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6943771529279821
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7014574314574316
# 10 of KFold 10
# ROC AUC score: 0.7087301587301587
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7045348085384134
# Std deviation: 0.005698026341184251
#
# TEST SET:
# F1-Score(micro): 0.7325896311581119
# F1-Score(macro): 0.6481833627310387
# F1-Score(weighted): 0.7555135558243907
# F1-Score(None): [0.82050727 0.47585945]
# Accuracy: 0.7325896311581119
# Sensitivity: 0.6436997777397846
# Specificity: 0.753248301347002
# Confusion Matrix: [0.753248301347002, 0.64]
# ROC AUC score: 0.6984740395433934
# CPU times: user 31.3 s, sys: 13.8 s, total: 45 s
# Wall time: 5.69 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 15 µs, sys: 0 ns, total: 15 µs
# Wall time: 4.29 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7960389822466246
# 2 of KFold 10
# ROC AUC score: 0.7951732510059835
# 3 of KFold 10
# ROC AUC score: 0.7865959243032062
# 4 of KFold 10
# ROC AUC score: 0.8026580765225322
# 5 of KFold 10
# ROC AUC score: 0.7886658162793707
# 6 of KFold 10
# ROC AUC score: 0.8022865558698291
# 7 of KFold 10
# ROC AUC score: 0.8046686878770513
# 8 of KFold 10
# ROC AUC score: 0.8104103426814314
# 9 of KFold 10
# ROC AUC score: 0.7916661116661117
# 10 of KFold 10
# ROC AUC score: 0.7975990675990676
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7975762816051208
# Std deviation: 0.0071137879203319295
#
# TEST SET:
# F1-Score(micro): 0.8890895021924168
# F1-Score(macro): 0.8134473003359524
# F1-Score(weighted): 0.8874349487138349
# F1-Score(None): [0.93223811 0.69465649]
# Accuracy: 0.8890895021924168
# Sensitivity: 0.6690032484185331
# Specificity: 0.9402392021297731
# Confusion Matrix: [0.9402392021297731, 0.67]
# ROC AUC score: 0.8046212252741531
# CPU times: user 5.29 s, sys: 11.4 ms, total: 5.3 s
# Wall time: 5.24 s

# %%
# %%time
RandomForest_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7749665082974383
# 2 of KFold 10
# ROC AUC score: 0.7883604779423092
# 3 of KFold 10
# ROC AUC score: 0.7853131951762089
# 4 of KFold 10
# ROC AUC score: 0.7815373523376407
# 5 of KFold 10
# ROC AUC score: 0.7841869249872133
# 6 of KFold 10
# ROC AUC score: 0.7832060833502794
# 7 of KFold 10
# ROC AUC score: 0.7875726372481962
# 8 of KFold 10
# ROC AUC score: 0.7819867635368716
# 9 of KFold 10
# ROC AUC score: 0.7776945276945277
# 10 of KFold 10
# ROC AUC score: 0.7836752136752136
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.78284996842459
# Std deviation: 0.0039054794683113987
#
# TEST SET:
# F1-Score(micro): 0.8887348465308228
# F1-Score(macro): 0.8040637899984557
# F1-Score(weighted): 0.8842872178317122
# F1-Score(None): [0.93286645 0.67526113]
# Accuracy: 0.8887348465308228
# Sensitivity: 0.6134381945631732
# Specificity: 0.9527158580681051
# Confusion Matrix: [0.9527158580681051, 0.61]
# ROC AUC score: 0.7830770263156391
# CPU times: user 57.1 s, sys: 22.2 ms, total: 57.2 s
# Wall time: 57.2 s

# %%
# %%time
NN_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7044469093351573
# 2 of KFold 10
# ROC AUC score: 0.7171012885216201
# 3 of KFold 10
# ROC AUC score: 0.7239099328933504
# 4 of KFold 10
# ROC AUC score: 0.7192345898113742
# 5 of KFold 10
# ROC AUC score: 0.7319964998551877
# 6 of KFold 10
# ROC AUC score: 0.7220516517848891
# 7 of KFold 10
# ROC AUC score: 0.7094751631449541
# 8 of KFold 10
# ROC AUC score: 0.7250210440044615
# 9 of KFold 10
# ROC AUC score: 0.7331734931734932
# 10 of KFold 10
# ROC AUC score: 0.7548096348096348
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7241220207334121
# Std deviation: 0.01328767847179672
#
# TEST SET:
# F1-Score(micro): 0.8914753675522311
# F1-Score(macro): 0.7905515658783764
# F1-Score(weighted): 0.8811064196050613
# F1-Score(None): [0.93594184 0.64516129]
# Accuracy: 0.8914753675522311
# Sensitivity: 0.5231663532227732
# Specificity: 0.9770731513489888
# Confusion Matrix: [0.9770731513489888, 0.52]
# ROC AUC score: 0.7501197522858809
# CPU times: user 14min 19s, sys: 7min 5s, total: 21min 25s
# Wall time: 2min 41s

# %% [markdown]
# ## Undersampling

# %%
print("Resampling dataset using Random UnderSampling (RUS)...")
X_RUS, y_RUS = RandomUnderSampler(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y RUS:", len(X_RUS), len(y_RUS))
# Out:
# Resampling dataset using Random UnderSampling (RUS)...
# ... DONE!
# X and Y RUS: 27736 27736

# %%
# %%time
LogisticRegr_(X_RUS, y_RUS, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7217479676465254
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7085940759282436
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7059499042165325
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.70432981530343
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6982688767956466
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7047555591890124
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.711672004312395
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6932995339727082
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7043712898003238
# 10 of KFold 10
# ROC AUC score: 0.6988901841520018
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7051879211316818
# Std deviation: 0.007476092348360426
#
# TEST SET:
# F1-Score(micro): 0.7334923910239877
# F1-Score(macro): 0.6484341321411771
# F1-Score(weighted): 0.7561396542372792
# F1-Score(None): [0.82136065 0.47550761]
# Accuracy: 0.7334923910239877
# Sensitivity: 0.64062232860318
# Specificity: 0.7550760917073946
# Confusion Matrix: [0.7550760917073946, 0.64]
# ROC AUC score: 0.6978492101552873
# CPU times: user 13.1 s, sys: 6.37 s, total: 19.4 s
# Wall time: 2.46 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 0 ns, sys: 19 µs, total: 19 µs
# Wall time: 5.25 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7373221613749816
# 2 of KFold 10
# ROC AUC score: 0.745263309906614
# 3 of KFold 10
# ROC AUC score: 0.7591440597084612
# 4 of KFold 10
# ROC AUC score: 0.7511600703605981
# 5 of KFold 10
# ROC AUC score: 0.7371670468035159
# 6 of KFold 10
# ROC AUC score: 0.7486134728580772
# 7 of KFold 10
# ROC AUC score: 0.7684894362606256
# 8 of KFold 10
# ROC AUC score: 0.738540793600888
# 9 of KFold 10
# ROC AUC score: 0.7552048874735832
# 10 of KFold 10
# ROC AUC score: 0.7879404312796005
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7528845669626946
# Std deviation: 0.015136918906765398
#
# TEST SET:
# F1-Score(micro): 0.8622323961826154
# F1-Score(macro): 0.7656899745100091
# F1-Score(weighted): 0.8593665279216023
# F1-Score(None): [0.91609229 0.61528766]
# Accuracy: 0.8622323961826154
# Sensitivity: 0.58420242776543
# Specificity: 0.9268486510112449
# Confusion Matrix: [0.9268486510112449, 0.58]
# ROC AUC score: 0.7555255393883374
# CPU times: user 2.12 s, sys: 22.6 ms, total: 2.14 s
# Wall time: 2.09 s

# %%
# %%time
RandomForest_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7247820294228469
# 2 of KFold 10
# ROC AUC score: 0.7265443984467764
# 3 of KFold 10
# ROC AUC score: 0.71678304872941
# 4 of KFold 10
# ROC AUC score: 0.7242532981530343
# 5 of KFold 10
# ROC AUC score: 0.7109851213103384
# 6 of KFold 10
# ROC AUC score: 0.7396100392413342
# 7 of KFold 10
# ROC AUC score: 0.7172488942631949
# 8 of KFold 10
# ROC AUC score: 0.6985623505441363
# 9 of KFold 10
# ROC AUC score: 0.7248056586595701
# 10 of KFold 10
# ROC AUC score: 0.7502518593717067
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7233826698142348
# Std deviation: 0.013604940833267591
#
# TEST SET:
# F1-Score(micro): 0.8633286045911788
# F1-Score(macro): 0.7468448413966665
# F1-Score(weighted): 0.8538001785035436
# F1-Score(None): [0.9185669  0.57512278]
# Accuracy: 0.8633286045911788
# Sensitivity: 0.4905111984954693
# Specificity: 0.9499741725275161
# Confusion Matrix: [0.9499741725275161, 0.49]
# ROC AUC score: 0.7202426855114927
# CPU times: user 21.4 s, sys: 661 µs, total: 21.4 s
# Wall time: 21.4 s

# %%
# %%time
NN_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7127069396774997
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.71725875292834
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7186343474708358
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7230061565523307
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7233787496832192
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.756041530412034
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7324751107450793
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7209656459817972
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.6944064298455568
# 10 of KFold 10
# ROC AUC score: 0.6885843825681484
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7187458045864842
# Std deviation: 0.01778992878870698
#
# TEST SET:
# F1-Score(micro): 0.8760639669847821
# F1-Score(macro): 0.7380304446337898
# F1-Score(weighted): 0.8564692642472067
# F1-Score(None): [0.9281898  0.54787109]
# Accuracy: 0.8760639669847821
# Sensitivity: 0.39818772439733285
# Specificity: 0.9871259983311479
# Confusion Matrix: [0.9871259983311479, 0.4]
# ROC AUC score: 0.6926568613642404
# CPU times: user 14min 56s, sys: 7min 24s, total: 22min 21s
# Wall time: 2min 48s
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
print("Resampling dataset using Edited Nearest Neighbour (ENN)...")
X_ENN, y_ENN = EditedNearestNeighbours(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y ENN:", len(X_ENN), len(y_ENN))
# Out:
# Resampling dataset using Edited Nearest Neighbour (ENN)...
# ... DONE!
# X and Y ENN: 64522 64522

# %%
# %%time
LogisticRegr_(X_ENN, y_ENN, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7004499670322712
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.71163739736987
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.702418050834683
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7064064591681681
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7046438101183661
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7033754858394148
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7097057105981552
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6915655943673185
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7014020921064071
# 10 of KFold 10
# ROC AUC score: 0.7085154610506474
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7040120028485302
# Std deviation: 0.00542528654598067
#
# TEST SET:
# F1-Score(micro): 0.7322672169202993
# F1-Score(macro): 0.6480806671238777
# F1-Score(weighted): 0.7552867164954842
# F1-Score(None): [0.82020526 0.47595608]
# Accuracy: 0.7322672169202992
# Sensitivity: 0.6447255941186527
# Specificity: 0.7526125481781698
# Confusion Matrix: [0.7526125481781698, 0.64]
# ROC AUC score: 0.6986690711484111
# CPU times: user 28.1 s, sys: 13 s, total: 41.1 s
# Wall time: 5.2 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 14 µs, sys: 6 µs, total: 20 µs
# Wall time: 5.25 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7926315196192728
# 2 of KFold 10
# ROC AUC score: 0.7983211855358062
# 3 of KFold 10
# ROC AUC score: 0.7780720228228944
# 4 of KFold 10
# ROC AUC score: 0.7982580352869899
# 5 of KFold 10
# ROC AUC score: 0.7879149872390726
# 6 of KFold 10
# ROC AUC score: 0.7950196906911667
# 7 of KFold 10
# ROC AUC score: 0.7982336407737953
# 8 of KFold 10
# ROC AUC score: 0.7928972607851917
# 9 of KFold 10
# ROC AUC score: 0.7900181494141797
# 10 of KFold 10
# ROC AUC score: 0.7949198910678329
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7926286383236202
# Std deviation: 0.005894731605600949
#
# TEST SET:
# F1-Score(micro): 0.8811903533660046
# F1-Score(macro): 0.7995927730877972
# F1-Score(weighted): 0.8792401913998791
# F1-Score(None): [0.92747062 0.67171492]
# Accuracy: 0.8811903533660046
# Sensitivity: 0.6445546247221747
# Specificity: 0.9361862756784678
# Confusion Matrix: [0.9361862756784678, 0.64]
# ROC AUC score: 0.7903704502003213
# CPU times: user 4.85 s, sys: 585 µs, total: 4.85 s
# Wall time: 4.83 s

# %%
# %%time
RandomForest_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7587177638151769
# 2 of KFold 10
# ROC AUC score: 0.7789946277937145
# 3 of KFold 10
# ROC AUC score: 0.7687314830043902
# 4 of KFold 10
# ROC AUC score: 0.7739700714958361
# 5 of KFold 10
# ROC AUC score: 0.7683654216671414
# 6 of KFold 10
# ROC AUC score: 0.7819721973440065
# 7 of KFold 10
# ROC AUC score: 0.7689029018868833
# 8 of KFold 10
# ROC AUC score: 0.7788914390207493
# 9 of KFold 10
# ROC AUC score: 0.7772163304838795
# 10 of KFold 10
# ROC AUC score: 0.7714417342826466
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7727203970794424
# Std deviation: 0.006572502369138624
#
# TEST SET:
# F1-Score(micro): 0.885704152695383
# F1-Score(macro): 0.7967789616274168
# F1-Score(weighted): 0.8805074229546562
# F1-Score(None): [0.93120913 0.6623488 ]
# Accuracy: 0.885704152695383
# Sensitivity: 0.5944605915541118
# Specificity: 0.9533913458099893
# Confusion Matrix: [0.9533913458099893, 0.59]
# ROC AUC score: 0.7739259686820505
# CPU times: user 51.8 s, sys: 1.79 ms, total: 51.8 s
# Wall time: 51.8 s

# %%
# %%time
NN_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7389584359553615
# 2 of KFold 10
# ROC AUC score: 0.7310515652710896
# 3 of KFold 10
# ROC AUC score: 0.71999236303158
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ROC AUC score: 0.7675354304983157
# 5 of KFold 10
# ROC AUC score: 0.7402209071116991
# 6 of KFold 10
# ROC AUC score: 0.7435779513233136
# 7 of KFold 10
# ROC AUC score: 0.7444361333909694
# 8 of KFold 10
# ROC AUC score: 0.7622589814400159
# 9 of KFold 10
# ROC AUC score: 0.7582177985795217
# 10 of KFold 10
# ROC AUC score: 0.7635767267437782
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7469826293345645
# Std deviation: 0.014723572882195984
#
# TEST SET:
# F1-Score(micro): 0.8933453701315449
# F1-Score(macro): 0.7950096661458521
# F1-Score(weighted): 0.8834394738730478
# F1-Score(None): [0.93698808 0.65303126]
# Accuracy: 0.893345370131545
# Sensitivity: 0.5322277312361088
# Specificity: 0.9772718242142489
# Confusion Matrix: [0.9772718242142489, 0.53]
# ROC AUC score: 0.7547497777251788
# CPU times: user 27min 36s, sys: 12min 51s, total: 40min 28s
# Wall time: 5min 4s

# %%
print("Resampling dataset using Tomek's Link (TL)...")
X_TL, y_TL = TomekLinks(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y TL:", len(X_TL), len(y_TL))
# Out:
# Resampling dataset using Tomek's Link (TL)...
# ... DONE!
# X and Y TL: 70614 70614

# %%
# %%time
LogisticRegr_(X_TL, y_TL, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7064628973830808
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7118133496101111
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7080839002792662
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7022503144741505
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7058315935799251
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6900963391336807
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7128798610267091
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6925758581306334
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.708397908804331
# 10 of KFold 10
# ROC AUC score: 0.7123243984038901
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7050716420825778
# Std deviation: 0.0075500758242475425
#
# TEST SET:
# F1-Score(micro): 0.7324284240392056
# F1-Score(macro): 0.6481612537696394
# F1-Score(weighted): 0.7554063420671215
# F1-Score(None): [0.82034852 0.47597398]
# Accuracy: 0.7324284240392056
# Sensitivity: 0.6443836553256967
# Specificity: 0.7528906901895339
# Confusion Matrix: [0.7528906901895339, 0.64]
# ROC AUC score: 0.6986371727576154
# CPU times: user 31.1 s, sys: 14 s, total: 45.2 s
# Wall time: 5.74 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 12 µs, sys: 5 µs, total: 17 µs
# Wall time: 5.25 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7902176284360383
# 2 of KFold 10
# ROC AUC score: 0.8074113693851399
# 3 of KFold 10
# ROC AUC score: 0.7895048565593157
# 4 of KFold 10
# ROC AUC score: 0.8073041399392595
# 5 of KFold 10
# ROC AUC score: 0.7922875491790244
# 6 of KFold 10
# ROC AUC score: 0.7862025627374759
# 7 of KFold 10
# ROC AUC score: 0.8107931530717875
# 8 of KFold 10
# ROC AUC score: 0.7907821696094167
# 9 of KFold 10
# ROC AUC score: 0.7963603242162242
# 10 of KFold 10
# ROC AUC score: 0.7985058590046644
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7969369612138346
# Std deviation: 0.008289095486001388
#
# TEST SET:
# F1-Score(micro): 0.8861555326283209
# F1-Score(macro): 0.8087631555495762
# F1-Score(weighted): 0.8845355918380152
# F1-Score(None): [0.93041953 0.68710678]
# Accuracy: 0.8861555326283209
# Sensitivity: 0.662848350145324
# Specificity: 0.9380538006119125
# Confusion Matrix: [0.9380538006119125, 0.66]
# ROC AUC score: 0.8004510753786183
# CPU times: user 5.39 s, sys: 34.3 ms, total: 5.43 s
# Wall time: 5.37 s

# %%
# %%time
RandomForest_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 3.58 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7772951314547797
# 2 of KFold 10
# ROC AUC score: 0.7873104736039801
# 3 of KFold 10
# ROC AUC score: 0.7810077798897886
# 4 of KFold 10
# ROC AUC score: 0.7858448408865044
# 5 of KFold 10
# ROC AUC score: 0.7857841201122333
# 6 of KFold 10
# ROC AUC score: 0.7802985193536596
# 7 of KFold 10
# ROC AUC score: 0.7822557070831954
# 8 of KFold 10
# ROC AUC score: 0.7716791810717373
# 9 of KFold 10
# ROC AUC score: 0.7853001908208367
# 10 of KFold 10
# ROC AUC score: 0.7825308013837448
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7819306745660459
# Std deviation: 0.004483619747448147
#
# TEST SET:
# F1-Score(micro): 0.887445189579572
# F1-Score(macro): 0.8008697305670648
# F1-Score(weighted): 0.882648847343927
# F1-Score(None): [0.93217013 0.66956933]
# Accuracy: 0.8874451895795719
# Sensitivity: 0.6047187553427936
# Specificity: 0.9531529383716772
# Confusion Matrix: [0.9531529383716772, 0.6]
# ROC AUC score: 0.7789358468572355
# CPU times: user 56.3 s, sys: 34.9 ms, total: 56.3 s
# Wall time: 56.3 s

# %%
# %%time
NN_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.7060666558431674
# 2 of KFold 10
# ROC AUC score: 0.729816001566256
# 3 of KFold 10
# ROC AUC score: 0.7166880918528497
# 4 of KFold 10
# ROC AUC score: 0.7242760144831851
# 5 of KFold 10
# ROC AUC score: 0.7413307702961257
# 6 of KFold 10
# ROC AUC score: 0.7330113508304379
# 7 of KFold 10
# ROC AUC score: 0.7394248832808761
# 8 of KFold 10
# ROC AUC score: 0.7291567631806396
# 9 of KFold 10
# ROC AUC score: 0.722320098753751
# 10 of KFold 10
# ROC AUC score: 0.7497363869260557
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7291827017013344
# Std deviation: 0.012048360370374865
#
# TEST SET:
# F1-Score(micro): 0.8913141604333248
# F1-Score(macro): 0.7890173817194608
# F1-Score(weighted): 0.8805194038148639
# F1-Score(None): [0.93592838 0.64210638]
# Accuracy: 0.8913141604333248
# Sensitivity: 0.517011454949564
# Specificity: 0.9783049231136012
# Confusion Matrix: [0.9783049231136012, 0.52]
# ROC AUC score: 0.7476581890315825
# CPU times: user 14min 56s, sys: 7min 25s, total: 22min 21s
# Wall time: 2min 48s

# %% [markdown]
# ## Oversampling

# %%
print("Resampling dataset using Random OverSampling (ROS)...")
ros = RandomOverSampler(random_state=42)
X_ROS, y_ROS = ros.fit_resample(X_train, y_train)
print("X and Y ROS:", len(X_ROS), len(y_ROS))
# Out:
# Resampling dataset using Random OverSampling (ROS)...
# X and Y ROS: 117000 117000
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# %%time
LogisticRegr_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.25 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7085470085470086
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7040170940170939
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7018803418803419
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7094871794871794
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7031623931623932
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7102564102564102
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.705042735042735
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6983760683760682
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7100000000000001
# 10 of KFold 10
# ROC AUC score: 0.7123931623931624
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7063162393162392
# Std deviation: 0.004250098295907317
#
# TEST SET:
# F1-Score(micro): 0.7328475625483621
# F1-Score(macro): 0.6485519145496261
# F1-Score(weighted): 0.7557555569485455
# F1-Score(None): [0.82067264 0.47643119]
# Accuracy: 0.7328475625483621
# Sensitivity: 0.6445546247221747
# Specificity: 0.753367505066158
# Confusion Matrix: [0.753367505066158, 0.64]
# ROC AUC score: 0.6989610648941664
# CPU times: user 57 s, sys: 24.1 s, total: 1min 21s
# Wall time: 10.2 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 9 µs, sys: 4 µs, total: 13 µs
# Wall time: 5.25 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.9644444444444445
# 2 of KFold 10
# ROC AUC score: 0.9629914529914531
# 3 of KFold 10
# ROC AUC score: 0.9595726495726496
# 4 of KFold 10
# ROC AUC score: 0.9656410256410257
# 5 of KFold 10
# ROC AUC score: 0.9716239316239317
# 6 of KFold 10
# ROC AUC score: 0.968119658119658
# 7 of KFold 10
# ROC AUC score: 0.9689743589743589
# 8 of KFold 10
# ROC AUC score: 0.9702564102564103
# 9 of KFold 10
# ROC AUC score: 0.968974358974359
# 10 of KFold 10
# ROC AUC score: 0.971111111111111
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.9671709401709403
# Std deviation: 0.003704800407428062
#
# TEST SET:
# F1-Score(micro): 0.8864779468661336
# F1-Score(macro): 0.8109153150101909
# F1-Score(weighted): 0.8853641813432914
# F1-Score(None): [0.93044663 0.691384  ]
# Accuracy: 0.8864779468661336
# Sensitivity: 0.674303299709352
# Specificity: 0.9357889299479477
# Confusion Matrix: [0.9357889299479477, 0.67]
# ROC AUC score: 0.80504611482865
# CPU times: user 9.26 s, sys: 26.1 ms, total: 9.29 s
# Wall time: 9.27 s

# %%
# %%time
RandomForest_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.9592307692307692
# 2 of KFold 10
# ROC AUC score: 0.9575213675213675
# 3 of KFold 10
# ROC AUC score: 0.957008547008547
# 4 of KFold 10
# ROC AUC score: 0.9621367521367522
# 5 of KFold 10
# ROC AUC score: 0.9647863247863248
# 6 of KFold 10
# ROC AUC score: 0.962051282051282
# 7 of KFold 10
# ROC AUC score: 0.9635897435897435
# 8 of KFold 10
# ROC AUC score: 0.9638461538461538
# 9 of KFold 10
# ROC AUC score: 0.9628205128205127
# 10 of KFold 10
# ROC AUC score: 0.9652991452991453
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.9618290598290598
# Std deviation: 0.00278616747497823
#
# TEST SET:
# F1-Score(micro): 0.8927327830797008
# F1-Score(macro): 0.8306110830395543
# F1-Score(weighted): 0.8945022080662034
# F1-Score(None): [0.93319143 0.72803074]
# Accuracy: 0.8927327830797008
# Sensitivity: 0.7613267225166696
# Specificity: 0.9232725394365637
# Confusion Matrix: [0.9232725394365637, 0.76]
# ROC AUC score: 0.8422996309766166
# CPU times: user 1min 43s, sys: 36.4 ms, total: 1min 43s
# Wall time: 1min 43s

# %%
# %%time
NN_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.8229059829059828
# 2 of KFold 10
# ROC AUC score: 0.8194871794871794
# 3 of KFold 10
# ROC AUC score: 0.8096581196581196
# 4 of KFold 10
# ROC AUC score: 0.8194017094017094
# 5 of KFold 10
# ROC AUC score: 0.8166666666666667
# 6 of KFold 10
# ROC AUC score: 0.823162393162393
# 7 of KFold 10
# ROC AUC score: 0.8223931623931623
# 8 of KFold 10
# ROC AUC score: 0.8283760683760686
# 9 of KFold 10
# ROC AUC score: 0.8226495726495727
# 10 of KFold 10
# ROC AUC score: 0.8320512820512821
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.8216752136752137
# Std deviation: 0.005806961143386285
#
# TEST SET:
# F1-Score(micro): 0.8503353108073253
# F1-Score(macro): 0.7827890094367176
# F1-Score(weighted): 0.8582318545961417
# F1-Score(None): [0.90391621 0.66166181]
# Accuracy: 0.8503353108073253
# Sensitivity: 0.7760300906137801
# Specificity: 0.8676044025906942
# Confusion Matrix: [0.8676044025906942, 0.78]
# ROC AUC score: 0.8218172466022371
# CPU times: user 10min 37s, sys: 5min 28s, total: 16min 6s
# Wall time: 2min 1s

# %%
print("Resampling dataset using SMOTE (SMO)...")
sm = SMOTE(random_state=42)
X_SMO, y_SMO = sm.fit_resample(X_train, y_train)
print("X and Y SMO:", len(X_SMO), len(y_SMO))
# Out:
# Resampling dataset using SMOTE (SMO)...
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# X and Y SMO: 117000 117000

# %%
# %%time
LogisticRegr_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 3.81 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.709059829059829
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7029914529914529
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7052991452991453
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7080341880341879
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.707008547008547
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7044444444444444
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7038461538461538
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7074358974358974
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7086324786324786
# 10 of KFold 10
# ROC AUC score: 0.7087179487179488
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7065470085470085
# Std deviation: 0.0021096399593942797
#
# TEST SET:
# F1-Score(micro): 0.7340404952282693
# F1-Score(macro): 0.6491424881345239
# F1-Score(weighted): 0.7566380443406571
# F1-Score(None): [0.8217319  0.47655308]
# Accuracy: 0.7340404952282693
# Sensitivity: 0.6419900837750043
# Specificity: 0.7554337028648627
# Confusion Matrix: [0.7554337028648627, 0.64]
# ROC AUC score: 0.6987118933199336
# CPU times: user 56.9 s, sys: 24.8 s, total: 1min 21s
# Wall time: 10.5 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.25 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.8346153846153845
# 2 of KFold 10
# ROC AUC score: 0.8418803418803419
# 3 of KFold 10
# ROC AUC score: 0.9094017094017094
# 4 of KFold 10
# ROC AUC score: 0.9429059829059829
# 5 of KFold 10
# ROC AUC score: 0.9434188034188035
# 6 of KFold 10
# ROC AUC score: 0.9398290598290598
# 7 of KFold 10
# ROC AUC score: 0.9423076923076923
# 8 of KFold 10
# ROC AUC score: 0.9425641025641027
# 9 of KFold 10
# ROC AUC score: 0.9427350427350426
# 10 of KFold 10
# ROC AUC score: 0.9435042735042735
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.9183162393162394
# Std deviation: 0.04125482724993903
#
# TEST SET:
# F1-Score(micro): 0.8573639411916429
# F1-Score(macro): 0.7820556844528694
# F1-Score(weighted): 0.8618497226099354
# F1-Score(None): [0.91016894 0.65394243]
# Accuracy: 0.857363941191643
# Sensitivity: 0.7146520772781672
# Specificity: 0.8905312512417054
# Confusion Matrix: [0.8905312512417054, 0.71]
# ROC AUC score: 0.8025916642599362
# CPU times: user 14.8 s, sys: 15.5 ms, total: 14.8 s
# Wall time: 14.8 s

# %%
# %%time
RandomForest_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.8913675213675214
# 2 of KFold 10
# ROC AUC score: 0.8829914529914531
# 3 of KFold 10
# ROC AUC score: 0.9335897435897436
# 4 of KFold 10
# ROC AUC score: 0.9589743589743589
# 5 of KFold 10
# ROC AUC score: 0.9613675213675213
# 6 of KFold 10
# ROC AUC score: 0.9596581196581196
# 7 of KFold 10
# ROC AUC score: 0.9603418803418804
# 8 of KFold 10
# ROC AUC score: 0.961111111111111
# 9 of KFold 10
# ROC AUC score: 0.9594871794871795
# 10 of KFold 10
# ROC AUC score: 0.9621367521367522
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.9431025641025641
# Std deviation: 0.0291414151358425
#
# TEST SET:
# F1-Score(micro): 0.8858331183905082
# F1-Score(macro): 0.8309268529265652
# F1-Score(weighted): 0.890936993590353
# F1-Score(None): [0.92727609 0.73457762]
# Accuracy: 0.8858331183905082
# Sensitivity: 0.8377500427423491
# Specificity: 0.8970079866491835
# Confusion Matrix: [0.8970079866491835, 0.84]
# ROC AUC score: 0.8673790146957662
# CPU times: user 2min 29s, sys: 24.3 ms, total: 2min 29s
# Wall time: 2min 29s

# %%
# %%time
NN_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.81 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.818974358974359
# 2 of KFold 10
# ROC AUC score: 0.8193162393162393
# 3 of KFold 10
# ROC AUC score: 0.8196581196581197
# 4 of KFold 10
# ROC AUC score: 0.8077777777777777
# 5 of KFold 10
# ROC AUC score: 0.8217094017094018
# 6 of KFold 10
# ROC AUC score: 0.814786324786325
# 7 of KFold 10
# ROC AUC score: 0.8217094017094018
# 8 of KFold 10
# ROC AUC score: 0.8217948717948719
# 9 of KFold 10
# ROC AUC score: 0.8125641025641026
# 10 of KFold 10
# ROC AUC score: 0.8234188034188035
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.8181709401709403
# Std deviation: 0.0046988651578484
#
# TEST SET:
# F1-Score(micro): 0.8346337374258447
# F1-Score(macro): 0.7668344650436232
# F1-Score(weighted): 0.8451451582501857
# F1-Score(None): [0.89256614 0.64110279]
# Accuracy: 0.8346337374258447
# Sensitivity: 0.7832108052658574
# Specificity: 0.8465848134461795
# Confusion Matrix: [0.8465848134461795, 0.78]
# ROC AUC score: 0.8148978093560185
# CPU times: user 11min 25s, sys: 5min 49s, total: 17min 15s
# Wall time: 2min 9s

# %%
print("Resampling dataset using ADASYN (ADA)...")
ada = ADASYN(random_state=42)
X_ADA, y_ADA = ada.fit_resample(X_train, y_train)
print("X and Y ADA:", len(X_ADA), len(y_ADA))
# Out:
# Resampling dataset using ADASYN (ADA)...
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# X and Y ADA: 116420 116420

# %%
# %%time
LogisticRegr_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 1 µs, sys: 1 µs, total: 2 µs
# Wall time: 4.05 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7141439710535014
# 2 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.7077712553713935
# 3 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.688483879916891
# 4 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6876461786372007
# 5 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6680366081125749
# 6 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6816665781272135
# 7 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6677621062945649
# 8 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.6691126280870756
# 9 of KFold 10
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)
# ROC AUC score: 0.667904064551164
# 10 of KFold 10
# ROC AUC score: 0.6664245407753696
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.6818951810926948
# Std deviation: 0.01666248007298045
#
# TEST SET:
# F1-Score(micro): 0.7214340985297911
# F1-Score(macro): 0.6435512767026845
# F1-Score(weighted): 0.747326994184823
# F1-Score(None): [0.8101683  0.47693425]
# Accuracy: 0.7214340985297911
# Sensitivity: 0.6734484527269619
# Specificity: 0.7325863233599555
# Confusion Matrix: [0.7325863233599555, 0.67]
# ROC AUC score: 0.7030173880434586
# CPU times: user 49.7 s, sys: 21.8 s, total: 1min 11s
# Wall time: 9.09 s
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:947: ConvergenceWarning: lbfgs failed to converge. Increase the number of iterations.
#   "of iterations.", ConvergenceWarning)

# %%
# %%time
DecisionTree_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 11 µs, sys: 4 µs, total: 15 µs
# Wall time: 5.25 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.845891503754073
# 2 of KFold 10
# ROC AUC score: 0.8377665922935259
# 3 of KFold 10
# ROC AUC score: 0.8995606967464703
# 4 of KFold 10
# ROC AUC score: 0.9265029572177362
# 5 of KFold 10
# ROC AUC score: 0.9376004922793597
# 6 of KFold 10
# ROC AUC score: 0.9323577170987392
# 7 of KFold 10
# ROC AUC score: 0.9392646503281863
# 8 of KFold 10
# ROC AUC score: 0.9382739823865515
# 9 of KFold 10
# ROC AUC score: 0.9326995974406196
# 10 of KFold 10
# ROC AUC score: 0.9395671601265523
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.9129485349671814
# Std deviation: 0.037321486778125655
#
# TEST SET:
# F1-Score(micro): 0.6268377611555326
# F1-Score(macro): 0.5756960048074752
# F1-Score(weighted): 0.6674453035752848
# F1-Score(None): [0.72300402 0.42838799]
# Accuracy: 0.6268377611555326
# Sensitivity: 0.7414942725252179
# Specificity: 0.6001907259506497
# Confusion Matrix: [0.6001907259506497, 0.74]
# ROC AUC score: 0.6708424992379338
# CPU times: user 14.1 s, sys: 4.07 ms, total: 14.1 s
# Wall time: 14.1 s

# %%
# %%time
RandomForest_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.8975862079142467
# 2 of KFold 10
# ROC AUC score: 0.8912998181989894
# 3 of KFold 10
# ROC AUC score: 0.9323662759125466
# 4 of KFold 10
# ROC AUC score: 0.9579196179817727
# 5 of KFold 10
# ROC AUC score: 0.9589478266515559
# 6 of KFold 10
# ROC AUC score: 0.9562016574585634
# 7 of KFold 10
# ROC AUC score: 0.9591076403645463
# 8 of KFold 10
# ROC AUC score: 0.9585042144779715
# 9 of KFold 10
# ROC AUC score: 0.959029873211503
# 10 of KFold 10
# ROC AUC score: 0.959438394248477
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.9430401526420173
# Std deviation: 0.025547226064894277
#
# TEST SET:
# F1-Score(micro): 0.8822220789270055
# F1-Score(macro): 0.8267813698947029
# F1-Score(weighted): 0.8878176505743645
# F1-Score(None): [0.92477812 0.72878462]
# Accuracy: 0.8822220789270054
# Sensitivity: 0.8391177979141734
# Specificity: 0.8922398378829419
# Confusion Matrix: [0.8922398378829419, 0.84]
# ROC AUC score: 0.8656788178985576
# CPU times: user 2min 26s, sys: 22.3 ms, total: 2min 26s
# Wall time: 2min 26s

# %%
# %%time
NN_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 10
# ROC AUC score: 0.8033868111630543
# 2 of KFold 10
# ROC AUC score: 0.8033065944184727
# 3 of KFold 10
# ROC AUC score: 0.7936088681116306
# 4 of KFold 10
# ROC AUC score: 0.7826882643906126
# 5 of KFold 10
# ROC AUC score: 0.7738754308920055
# 6 of KFold 10
# ROC AUC score: 0.7734496741748123
# 7 of KFold 10
# ROC AUC score: 0.7744154035038014
# 8 of KFold 10
# ROC AUC score: 0.7785940229966473
# 9 of KFold 10
# ROC AUC score: 0.7782419901308023
# 10 of KFold 10
# ROC AUC score: 0.7826233354582803
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7844190395240119
# Std deviation: 0.011003832629998702
#
# TEST SET:
# F1-Score(micro): 0.7873678101624967
# F1-Score(macro): 0.7267660670798459
# F1-Score(weighted): 0.8069128783943285
# F1-Score(None): [0.85544572 0.59808642]
# Accuracy: 0.7873678101624968
# Sensitivity: 0.8389468285176953
# Specificity: 0.775380458536973
# Confusion Matrix: [0.775380458536973, 0.84]
# ROC AUC score: 0.8071636435273342
# CPU times: user 19min 31s, sys: 9min 21s, total: 28min 53s
# Wall time: 3min 37s
