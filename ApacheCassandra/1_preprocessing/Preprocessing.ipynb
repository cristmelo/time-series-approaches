# %%
import pandas as pd
import numpy as np

# %%
print("Reading CSV and choosing selected kind classes only...")
release_01_df = pd.read_csv('originalReleases/2010-03-13T23-17-20Z-cassandra-0.4.1.csv', sep=',', index_col=False)
release_02_df = pd.read_csv('originalReleases/2010-03-13T23-17-20Z-cassandra-0.4.2.csv', sep=',', index_col=False)
release_03_df = pd.read_csv('originalReleases/2010-03-13T23-17-20Z-cassandra-0.5.0.csv', sep=',', index_col=False)
release_04_df = pd.read_csv('originalReleases/2010-04-12T01-37-17Z-cassandra-0.6.0.csv', sep=',', index_col=False)
release_05_df = pd.read_csv('originalReleases/2010-04-15T13-48-48Z-cassandra-0.6.1.csv', sep=',', index_col=False)
release_06_df = pd.read_csv('originalReleases/2010-07-27T21-48-02Z-cassandra-0.6.4.csv', sep=',', index_col=False)
release_07_df = pd.read_csv('originalReleases/2010-11-10T15-18-01Z-cassandra-0.6.7.csv', sep=',', index_col=False)
release_08_df = pd.read_csv('originalReleases/2011-01-10T00-38-51Z-cassandra-0.7.0.csv', sep=',', index_col=False)
release_09_df = pd.read_csv('originalReleases/2011-05-18T13-32-14Z-cassandra-0.7.6.csv', sep=',', index_col=False)
release_10_df = pd.read_csv('originalReleases/2011-07-16T14-07-06Z-cassandra-0.7.7.csv', sep=',', index_col=False)
release_11_df = pd.read_csv('originalReleases/2011-09-08T11-19-13Z-cassandra-0.8.5.csv', sep=',', index_col=False)
release_12_df = pd.read_csv('originalReleases/2011-10-18T11-24-49Z-cassandra-1.0.0.csv', sep=',', index_col=False)
release_13_df = pd.read_csv('originalReleases/2011-11-29T08-21-06Z-cassandra-1.0.4.csv', sep=',', index_col=False)
release_14_df = pd.read_csv('originalReleases/2012-05-08T06-29-08Z-cassandra-1.0.10.csv', sep=',', index_col=False)
release_15_df = pd.read_csv('originalReleases/2012-06-04T18-48-23Z-cassandra-1.1.1.csv', sep=',', index_col=False)
release_16_df = pd.read_csv('originalReleases/2012-07-02T18-23-17Z-cassandra-1.1.2.csv', sep=',', index_col=False)
release_17_df = pd.read_csv('originalReleases/2012-10-15T16-14-05Z-cassandra-1.1.6.csv', sep=',', index_col=False)
release_18_df = pd.read_csv('originalReleases/2013-01-02T09-37-23Z-cassandra-1.2.0.csv', sep=',', index_col=False)
release_19_df = pd.read_csv('originalReleases/2013-09-23T06-44-00Z-cassandra-1.2.10.csv', sep=',', index_col=False)
release_20_df = pd.read_csv('originalReleases/2013-10-28T09-09-18Z-cassandra-2.0.2.csv', sep=',', index_col=False)
release_21_df = pd.read_csv('originalReleases/2014-02-07T07-34-05Z-cassandra-1.2.15.csv', sep=',', index_col=False)
release_22_df = pd.read_csv('originalReleases/2014-03-10T15-03-19Z-cassandra-2.0.6.csv', sep=',', index_col=False)
release_23_df = pd.read_csv('originalReleases/2014-07-03T15-27-55Z-cassandra-1.2.18.csv', sep=',', index_col=False)
release_24_df = pd.read_csv('originalReleases/2014-08-25T16-45-28Z-cassandra-2.0.10.csv', sep=',', index_col=False)
release_25_df = pd.read_csv('originalReleases/2014-09-16T09-38-43Z-cassandra-2.1.0.csv', sep=',', index_col=False)
release_26_df = pd.read_csv('originalReleases/2014-10-24T16-19-23Z-cassandra-2.1.1.csv', sep=',', index_col=False)
release_27_df = pd.read_csv('originalReleases/2014-10-24T16-57-41Z-cassandra-2.0.11.csv', sep=',', index_col=False)
release_28_df = pd.read_csv('originalReleases/2014-11-10T15-40-32Z-cassandra-2.1.2.csv', sep=',', index_col=False)
release_29_df = pd.read_csv('originalReleases/2015-06-08T13-40-03Z-cassandra-2.1.6.csv', sep=',', index_col=False)
release_30_df = pd.read_csv('originalReleases/2015-07-20T10-08-26Z-cassandra-2.2.0.csv', sep=',', index_col=False)
release_31_df = pd.read_csv('originalReleases/2015-10-16T12-44-14Z-cassandra-2.2.3.csv', sep=',', index_col=False)
release_32_df = pd.read_csv('originalReleases/2015-10-16T12-50-36Z-cassandra-2.1.11.csv', sep=',', index_col=False)
release_33_df = pd.read_csv('originalReleases/2015-11-09T17-36-30Z-cassandra-3.0.0.csv', sep=',', index_col=False)
release_34_df = pd.read_csv('originalReleases/2015-12-07T14-16-41Z-cassandra-2.2.4.csv', sep=',', index_col=False)
release_35_df = pd.read_csv('originalReleases/2016-03-08T02-54-42Z-cassandra-3.4.csv', sep=',', index_col=False)
release_36_df = pd.read_csv('originalReleases/2016-03-08T03-00-48Z-cassandra-3.0.4.csv', sep=',', index_col=False)
release_37_df = pd.read_csv('originalReleases/2016-04-11T01-14-18Z-cassandra-3.0.5.csv', sep=',', index_col=False)
release_38_df = pd.read_csv('originalReleases/2016-04-13T14-51-51Z-cassandra-3.5.csv', sep=',', index_col=False)
release_39_df = pd.read_csv('originalReleases/2016-09-29T19-34-56Z-cassandra-3.8.csv', sep=',', index_col=False)
release_40_df = pd.read_csv('originalReleases/2017-02-03T21-59-56Z-cassandra-3.10.csv', sep=',', index_col=False)
release_41_df = pd.read_csv('originalReleases/2017-06-23T19-40-53Z-cassandra-3.0.14.csv', sep=',', index_col=False)
release_42_df = pd.read_csv('originalReleases/2017-06-23T20-02-37Z-cassandra-3.11.01.csv', sep=',', index_col=False)
release_43_df = pd.read_csv('originalReleases/2017-06-26T21-51-39Z-cassandra-2.1.18.csv', sep=',', index_col=False)
release_44_df = pd.read_csv('originalReleases/2017-06-26T21-53-20Z-cassandra-2.2.10.csv', sep=',', index_col=False)
release_45_df = pd.read_csv('originalReleases/2017-10-10T20-26-12Z-cassandra-3.11.1.csv', sep=',', index_col=False)
release_46_df = pd.read_csv('originalReleases/2019-02-11T22-15-18Z-cassandra-3.11.4.csv', sep=',', index_col=False)
release_47_df = pd.read_csv('originalReleases/2019-02-11T22-42-53Z-cassandra-3.0.18.csv', sep=',', index_col=False)
release_48_df = pd.read_csv('originalReleases/2019-02-11T22-59-09Z-cassandra-2.2.14.csv', sep=',', index_col=False)
release_49_df = pd.read_csv('originalReleases/2019-02-11T23-15-39Z-cassandra-2.1.21.csv', sep=',', index_col=False)
print("... DONE!")
# Out:
# Reading CSV and choosing selected kind classes only...
# ... DONE!

# %%
list_of_columns_I_want = ['Kind','Name','File','CountClassCoupled','CountDeclMethod','CountDeclMethodAll',
                          'CountClassDerived','CountLineCode','SumCyclomatic','PercentLackOfCohesion','MaxInheritanceTree']

# %%
release_01_df = release_01_df[list_of_columns_I_want]
release_02_df = release_02_df[list_of_columns_I_want]
release_03_df = release_03_df[list_of_columns_I_want]
release_04_df = release_04_df[list_of_columns_I_want]
release_05_df = release_05_df[list_of_columns_I_want]
release_06_df = release_06_df[list_of_columns_I_want]
release_07_df = release_07_df[list_of_columns_I_want]
release_08_df = release_08_df[list_of_columns_I_want]
release_09_df = release_09_df[list_of_columns_I_want]
release_10_df = release_10_df[list_of_columns_I_want]
release_11_df = release_11_df[list_of_columns_I_want]
release_12_df = release_12_df[list_of_columns_I_want]
release_13_df = release_13_df[list_of_columns_I_want]
release_14_df = release_14_df[list_of_columns_I_want]
release_15_df = release_15_df[list_of_columns_I_want]
release_16_df = release_16_df[list_of_columns_I_want]
release_17_df = release_17_df[list_of_columns_I_want]
release_18_df = release_18_df[list_of_columns_I_want]
release_19_df = release_19_df[list_of_columns_I_want]
release_20_df = release_20_df[list_of_columns_I_want]
release_21_df = release_21_df[list_of_columns_I_want]
release_22_df = release_22_df[list_of_columns_I_want]
release_23_df = release_23_df[list_of_columns_I_want]
release_24_df = release_24_df[list_of_columns_I_want]
release_25_df = release_25_df[list_of_columns_I_want]
release_26_df = release_26_df[list_of_columns_I_want]
release_27_df = release_27_df[list_of_columns_I_want]
release_28_df = release_28_df[list_of_columns_I_want]
release_29_df = release_29_df[list_of_columns_I_want]
release_30_df = release_30_df[list_of_columns_I_want]
release_31_df = release_31_df[list_of_columns_I_want]
release_32_df = release_32_df[list_of_columns_I_want]
release_33_df = release_33_df[list_of_columns_I_want]
release_34_df = release_34_df[list_of_columns_I_want]
release_35_df = release_35_df[list_of_columns_I_want]
release_36_df = release_36_df[list_of_columns_I_want]
release_37_df = release_37_df[list_of_columns_I_want]
release_38_df = release_38_df[list_of_columns_I_want]
release_39_df = release_39_df[list_of_columns_I_want]
release_40_df = release_40_df[list_of_columns_I_want]
release_41_df = release_41_df[list_of_columns_I_want]
release_42_df = release_42_df[list_of_columns_I_want]
release_43_df = release_43_df[list_of_columns_I_want]
release_44_df = release_44_df[list_of_columns_I_want]
release_45_df = release_45_df[list_of_columns_I_want]
release_46_df = release_46_df[list_of_columns_I_want]
release_47_df = release_47_df[list_of_columns_I_want]
release_48_df = release_48_df[list_of_columns_I_want]
release_49_df = release_49_df[list_of_columns_I_want]

# %%
print("Dataframe containing the chronological order of all releases...")
time_based_df_list = [release_01_df, release_02_df, release_03_df, release_04_df, release_05_df, release_06_df, release_07_df, 
        release_08_df, release_09_df, release_10_df, release_11_df, release_12_df, release_13_df, release_14_df, release_15_df,
        release_16_df, release_17_df, release_18_df, release_19_df, release_20_df, release_21_df, release_22_df, release_23_df,
        release_24_df, release_25_df, release_26_df, release_27_df, release_28_df, release_29_df, release_30_df, release_31_df,
        release_32_df, release_33_df, release_34_df, release_35_df, release_36_df, release_37_df, release_38_df, release_39_df,
        release_40_df, release_41_df, release_42_df, release_43_df, release_44_df, release_45_df, release_46_df, release_47_df,
        release_48_df, release_49_df]
print("... DONE!")
print("Dataframe containing the inverse chronological order of all releases")
reverse_time_based_df_list = [release_49_df, release_48_df, release_47_df, release_46_df, release_45_df, release_44_df, release_43_df, 
        release_42_df, release_41_df, release_40_df, release_39_df, release_38_df, release_37_df, release_36_df, release_35_df,
        release_34_df, release_33_df, release_32_df, release_31_df, release_30_df, release_29_df, release_28_df, release_27_df,
        release_26_df, release_25_df, release_24_df, release_23_df, release_22_df, release_21_df, release_20_df, release_19_df,
        release_18_df, release_17_df, release_16_df, release_15_df, release_14_df, release_13_df, release_12_df, release_11_df, 
        release_10_df, release_09_df, release_08_df, release_07_df, release_06_df, release_05_df, release_04_df, release_03_df, 
        release_02_df, release_01_df]
print("... DONE!")
# Out:
# Dataframe containing the chronological order of all releases...
# ... DONE!
# Dataframe containing the inverse chronological order of all releases
# ... DONE!

# %%
print("Selecting only the necessary domain on KIND column")
domain_selected = ['Abstract Class',
'Class',
'Public Class',
'Anonymous Class',
'Public Static Class',
'Static Class',
'Private Static Class',
'Private Class',
'Private Static Generic Class',
'Public Generic Class',
'Protected Class',
'Public Static Generic Class',
'Protected Static Class',
'Public Abstract Class',
'Generic Class',
'Static Generic Class',
'Private Generic Class',
'Public Abstract Generic Class',
'Public Static Abstract Class',
'Static Abstract Class',
'Private Static Abstract Class',
'Public Static Abstract Generic Class',
'Static Abstract Generic Class',
'Abstract Generic Class',
'Private Abstract Generic Class',
'Private Static Abstract Generic Class',
'Protected Static Abstract Generic Class',
'Protected Static Generic Class']
print("... DONE!")
# Out:
# Selecting only the necessary domain on KIND column
# ... DONE!

# %%
print("Checking total of lines for each selected kind, including .java and .py files")
for release in time_based_df_list:
    print("")
    for col in domain_selected:    
        print((col), len(release.loc[release['Kind'] == col]))
print("... DONE!")
# Out:
# Checking total of lines for each selected kind, including .java and .py files
#
# Abstract Class 0
# Class 79
# Public Class 207
# Anonymous Class 73
# Public Static Class 51
# Static Class 9
# Private Static Class 3
# Private Class 16
# Private Static Generic Class 0
# Public Generic Class 5
# Protected Class 1
# Public Static Generic Class 0
# Protected Static Class 3
# Public Abstract Class 11
# Generic Class 1
# Static Generic Class 0
# Private Generic Class 1
# Public Abstract Generic Class 4
# Public Static Abstract Class 0
# Static Abstract Class 0
# Private Static Abstract Class 0
# Public Static Abstract Generic Class 1
# Static Abstract Generic Class 0
# Abstract Generic Class 0
# Private Abstract Generic Class 1
# Private Static Abstract Generic Class 0
# Protected Static Abstract Generic Class 0
# Protected Static Generic Class 0
#
# Abstract Class 0
# Class 79
# Public Class 208
# Anonymous Class 73
# Public Static Class 51
# Static Class 9
# Private Static Class 3
# ...

# %%
print("Filtering only by '.java' files")
df_java = list()
df_java_temp = list()
for release in time_based_df_list:
    df_java_temp = release[release['File'].str.contains(".java", na=False)]
    df_java.append(df_java_temp)
print("... DONE!")
# Out:
# Filtering only by '.java' files
# ... DONE!

# %%
print("filtering by selected classes on KIND...")
ds_df = list()
for i in df_java:
    ds_df_temp = i[i['Kind'].isin(domain_selected)]
    ds_df.append(ds_df_temp)
print("... DONE!")
# Out:
# filtering by selected classes on KIND...
# ... DONE!

# %% [markdown]
# ## DATASET

# %%
print("The dataset below contains only java files and kind column containing 'classes' in the name:")
ds_df
# Out:
# The dataset below contains only java files and kind column containing 'classes' in the name:
# [                                Kind  \
#  301                     Public Class
#  303                     Public Class
#  308                     Public Class
#  309              Public Static Class
#  311              Public Static Class
#  321                     Public Class
#  332                     Public Class
#  333              Public Static Class
#  342                     Public Class
#  349                     Public Class
#  352                     Public Class
#  354                     Public Class
#  357                     Public Class
#  361                     Public Class
#  365                     Public Class
#  386                     Public Class
#  391                     Public Class
#  394                     Public Class
#  413                     Public Class
#  425                     Public Class
#  437                     Public Class
# ...

# %%
print("Checking if new dataframe contains NaN values...")
for j in ds_df:
    print(j.isnull().values.any())
print("... DONE!")
# Out:
# Checking if new dataframe contains NaN values...
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ... DONE!

# %% [raw]
# print("Preparing to generate releases... ")
# for i in range(len(ds_df)):
#     print("Generating release", i+1 )
#     ds_df[i].to_csv('outputReleases/release'+str(i+1)+'.csv', index=False)
# print("... DONE!")

# %%
print("including four new columns into dataframe...")
for df in ds_df:
    df.loc[:,'Path'] = df.Name+'.'+df.File
    df.loc[:,'class_frequency'] = 1
    df.loc[:,'will_change'] = 0
    df.loc[:,'number_of_changes'] = 0
    df.loc[:,'release'] = 0
print("... DONE!")
# Out:
# including four new columns into dataframe...
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ... DONE!

# %%
print("Labeling each release...")
for i in range(ds_df.__len__()):
    ds_df[i].release = i+1
print("... DONE!")
# Out:
# Labeling each release...
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py:5096: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# ... DONE!

# %%
ds_df[0].head()
# Out:
#                     Kind                                               Name  \
# 301         Public Class                 org.apache.cassandra.CleanupHelper
# 303         Public Class                          org.apache.cassandra.Util
# 308         Public Class  org.apache.cassandra.bulkloader.CassandraBulkL...
# 309  Public Static Class  org.apache.cassandra.bulkloader.CassandraBulkL...
# 311  Public Static Class  org.apache.cassandra.bulkloader.CassandraBulkL...
#
#                          File  CountClassCoupled  CountDeclMethod  \
# 301        CleanupHelper.java                1.0              1.0
# 303                 Util.java                3.0              3.0
# 308  CassandraBulkLoader.java               13.0              5.0
# 309  CassandraBulkLoader.java                0.0              1.0
# 311  CassandraBulkLoader.java                9.0              3.0
#
#      CountDeclMethodAll  CountClassDerived  CountLineCode  SumCyclomatic  \
# ...

# %%
for i in range(ds_df.__len__() - 1):
    previous_df = ds_df[i]
    next_df = ds_df[i + 1]
    
    keep_classes_list = list(set(previous_df['Path']).intersection(set(next_df['Path'])))
    
    for keep_class in keep_classes_list:
        previous_keep_class_row = previous_df.loc[previous_df['Path'] == keep_class]
        next_keep_class_row = next_df.loc[next_df['Path'] == keep_class]     
        previous_keep_class_row_values_list = list(previous_keep_class_row.values[0][:])
        next_keep_class_row_values_list = list(next_keep_class_row.values[0][:])
        
        # THE NUMBER INTO BRACKETS BELOW REFERS TO LOC INDEX (COUNT LINE CODE, column 7, in this case)
        if previous_keep_class_row_values_list[7] != next_keep_class_row_values_list[7]:
            previous_df.at[previous_keep_class_row.index.get_values(), 'will_change'] = 1
            next_df.at[next_keep_class_row.index.get_values(), 'number_of_changes'] = previous_keep_class_row_values_list[-1] + 1
        else:
            next_df.at[next_keep_class_row.index.get_values(), 'number_of_changes'] = previous_keep_class_row_values_list[-1]
        
        # THE NUMBER INTO BRACKETS BELOW REFERS TO CLASS_FREQUENCY INDEX (column 12, in this case)
        next_df.at[next_keep_class_row.index.get_values(), 'class_frequency'] = previous_keep_class_row_values_list[12] + 1
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
all_releases_df = pd.concat(ds_df, ignore_index=True)

# %%
all_releases_df
# Out:
#                          Kind  \
# 0                Public Class
# 1                Public Class
# 2                Public Class
# 3         Public Static Class
# 4         Public Static Class
# 5                Public Class
# 6                Public Class
# 7         Public Static Class
# 8                Public Class
# 9                Public Class
# 10               Public Class
# 11               Public Class
# 12               Public Class
# 13               Public Class
# 14               Public Class
# 15               Public Class
# 16               Public Class
# 17               Public Class
# 18               Public Class
# 19               Public Class
# 20               Public Class
# 21               Public Class
# 22               Public Class
# 23               Public Class
# 24               Public Class
# 25       Private Static Class
# 26               Public Class
# 27               Public Class
# 28               Public Class
# 29               Public Class
# ...

# %% [raw]
# all_releases_df.to_excel("all_releases.xlsx")

# %%
all_releases_df.to_csv('all_releases.csv', index=False)
