# %%
# %run auxiliary.ipynb
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preprocessing

# %%
print("Setting general dataframe...")
all_releases_df = pd.read_csv('all_releases.csv')
print("Total of instances:", all_releases_df.shape[0])
print("... DONE!")

print("Filtering required columns into X features...")
X = all_releases_df.drop(columns=['File', 'Kind', 'Name','Path', 'class_frequency', 'number_of_changes', 'release', 'will_change'])
print("... DONE!")

print("Setting y column containing label of change-proneness...")
y = pd.DataFrame(all_releases_df.loc[:,'will_change'])
print("... DONE!")

print("Declaring a dictionary to save results...")
results_dict = dict()
print("... DONE!")

print("Splitting dataset into train and test sets...")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)
print("General information:")
print("X Train set:", X_train.shape[0], "X Test set:", X_test.shape[0])
print("y Train set:", y_train.shape[0], "y Test set:", y_test.shape[0])
print("... DONE!")
# Out:
# Setting general dataframe...
# Total of instances: 100640
# ... DONE!
# Filtering required columns into X features...
# ... DONE!
# Setting y column containing label of change-proneness...
# ... DONE!
# Declaring a dictionary to save results...
# ... DONE!
# Splitting dataset into train and test sets...
# General information:
# X Train set: 70448 X Test set: 30192
# y Train set: 70448 y Test set: 30192
# ... DONE!

# %% [markdown]
# ## Outliers removal

# %%
wo_outliers_df = pd.DataFrame()
only_1_df = X_train.loc[y_train[y_train.will_change == 1].index]
only_0_df = X_train.loc[y_train[y_train.will_change == 0].index]

# %%
print("Checking outliers in label zero")
boxplot_caps = only_0_df.boxplot(figsize=(10, 10), return_type='dict')['caps']
# Out:
# Checking outliers in label zero

# %%
boxplot_max_list = list()
for i in range(1,16,2):
    boxplot_max_list.append(boxplot_caps[i].get_ydata()[0])

# %%
outliers_index_list = outliers_counter(only_0_df)

# %%
print("Amount of outliers in label zero")
outliers_index_list.__len__()
# Out:
# Amount of outliers in label zero
# 2403

# %%
only_0_df = only_0_df.drop(outliers_index_list)

# %%
print("Checking outliers in label one")
boxplot_caps = only_1_df.boxplot(figsize=(10, 10), return_type='dict')['caps']
# Out:
# Checking outliers in label one

# %%
boxplot_max_list = list()
for i in range(1,16,2):
    boxplot_max_list.append(boxplot_caps[i].get_ydata()[0])

# %%
outliers_index_list = outliers_counter(only_1_df)

# %%
print("Amount of outliers in label one")
outliers_index_list.__len__()
# Out:
# Amount of outliers in label one
# 566

# %%
only_1_df = only_1_df.drop(outliers_index_list)

# %%
X_train = wo_outliers_df.append([only_0_df, only_1_df])

# %%
y_train = y_train.loc[X_train.index]

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (67479, 8)
# (67479, 1)

# %%
print("Scaling features...")
scaler = MinMaxScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_test = pd.DataFrame(scaler.fit_transform(X_test))
print("... DONE!")

print("Setting stratified k-fold...")
k=5
kf = StratifiedKFold(n_splits=k, shuffle=False, random_state=42)
print("k =", k)
print("... DONE!\n")
# Out:
# Scaling features...
# ... DONE!
# Setting stratified k-fold...
# k = 5
# ... DONE!

# %% [markdown]
# ## Statistical Analysis

# %%
all_releases_df.describe()
# Out:
#        CountClassCoupled  CountClassDerived  CountDeclMethod  \
# count      100640.000000      100640.000000    100640.000000
# mean            5.338504           0.448698         4.287997
# std             7.230259          11.276201         5.618115
# min             0.000000           0.000000         0.000000
# 25%             1.000000           0.000000         1.000000
# 50%             3.000000           0.000000         2.000000
# 75%             7.000000           0.000000         5.000000
# max           106.000000         901.000000       100.000000
#
#        CountDeclMethodAll  CountLineCode  MaxInheritanceTree  \
# count       100640.000000  100640.000000       100640.000000
# mean             8.674672      57.746343            1.625735
# std              8.966859     117.082274            0.759659
# min              0.000000       0.000000            1.000000
# 25%              2.000000       8.000000            1.000000
# 50%              6.000000      22.000000            1.000000
# 75%             11.000000      57.000000            2.000000
# max            100.000000    2749.000000            6.000000
#
#        PercentLackOfCohesion  SumCyclomatic  class_frequency  \
# count          100640.000000  100640.000000    100640.000000
# mean               17.538782       5.891107         6.378975
# std                28.567063       9.420142         4.120797
# min                 0.000000       0.000000         1.000000
# 25%                 0.000000       1.000000         3.000000
# 50%                 0.000000       3.000000         6.000000
# 75%                33.000000       7.000000         9.000000
# max               100.000000     179.000000        15.000000
#
#        number_of_changes        release    will_change
# count      100640.000000  100640.000000  100640.000000
# mean            7.580535       8.864159       0.167548
# std             4.492134       4.233281       0.373466
# min             0.000000       1.000000       0.000000
# 25%             4.000000       5.000000       0.000000
# 50%             8.000000       9.000000       0.000000
# 75%            12.000000      13.000000       0.000000
# max            15.000000      15.000000       1.000000

# %%
ax = y_train.groupby(['will_change'])['will_change'].count().plot.bar(title="Class Distribution", figsize=(5,5))
y_train.groupby(['will_change'])['will_change'].count()
# Out:
# will_change
# 0    56196
# 1    11283
# Name: will_change, dtype: int64

# %%
X_train.corr(method='spearman').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col2 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col4 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col6 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row0_col7 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col4 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row1_col7 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col0 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col1 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col3 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col4 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col6 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row2_col7 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col0 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col2 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col4 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col5 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col6 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row3_col7 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col0 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col1 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col2 {
#             background-color:  #e97a5f;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col3 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col6 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row4_col7 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col0 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col1 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col2 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col3 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col6 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row5_col7 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col1 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col2 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col3 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col4 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row6_col7 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row7_col0 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row7_col1 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row7_col2 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_b84afbda_1d9f_11ea_95e7_e0d55eb0dab9row7_col3 {
#             background-color:  #cdd9ec;
#             color:  #000000;

# %% [markdown]
# ## Imbalanced baseline

# %%
# %%time
LogisticRegr_(X_train, y_train, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.5922538145461254
# 2 of KFold 5
# ROC AUC score: 0.586848055005627
# 3 of KFold 5
# ROC AUC score: 0.5878113756914012
# 4 of KFold 5
# ROC AUC score: 0.5856194338798725
# 5 of KFold 5
# ROC AUC score: 0.5845363614793724
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5874138081204796
# Std deviation: 0.002660950087787434
#
# TEST SET:
# F1-Score(micro): 0.7239003709591945
# F1-Score(macro): 0.5685728949739338
# F1-Score(weighted): 0.7414771718959237
# F1-Score(None): [0.82744059 0.3097052 ]
# Accuracy: 0.7239003709591945
# Sensitivity: 0.3730301216836226
# Specificity: 0.7937567020135827
# Confusion Matrix: [0.7937567020135827, 0.37]
# ROC AUC score: 0.5833934118486026
# CPU times: user 4.31 s, sys: 2.51 s, total: 6.82 s
# Wall time: 873 ms

# %%
# %%time
DecisionTree_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 9 µs, sys: 2 µs, total: 11 µs
# Wall time: 2.86 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6386819298442016
# 2 of KFold 5
# ROC AUC score: 0.6407748739347287
# 3 of KFold 5
# ROC AUC score: 0.647732279793647
# 4 of KFold 5
# ROC AUC score: 0.6451726794804565
# 5 of KFold 5
# ROC AUC score: 0.6558134028922844
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.6456350331890637
# Std deviation: 0.006002969568298202
#
# TEST SET:
# F1-Score(micro): 0.6342077371489137
# F1-Score(macro): 0.5187970876202652
# F1-Score(weighted): 0.6762007910150117
# F1-Score(None): [0.75445773 0.28313644]
# Accuracy: 0.6342077371489137
# Sensitivity: 0.4350688210652304
# Specificity: 0.6738551967909766
# Confusion Matrix: [0.6738551967909766, 0.44]
# ROC AUC score: 0.5544620089281036
# CPU times: user 593 ms, sys: 15.7 ms, total: 609 ms
# Wall time: 576 ms

# %%
# %%time
RandomForest_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.62 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6192650740992436
# 2 of KFold 5
# ROC AUC score: 0.623229160059343
# 3 of KFold 5
# ROC AUC score: 0.6322765925649037
# 4 of KFold 5
# ROC AUC score: 0.6286643591306614
# 5 of KFold 5
# ROC AUC score: 0.629876852796651
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.6266624077301606
# Std deviation: 0.004740617518222292
#
# TEST SET:
# F1-Score(micro): 0.7566905140434552
# F1-Score(macro): 0.543758421239601
# F1-Score(weighted): 0.7519417133700443
# F1-Score(None): [0.85544492 0.23207192]
# Accuracy: 0.7566905140434552
# Sensitivity: 0.22142429682824655
# Specificity: 0.8632590650939275
# Confusion Matrix: [0.8632590650939275, 0.22]
# ROC AUC score: 0.5423416809610869
# CPU times: user 12.1 s, sys: 28.1 ms, total: 12.1 s
# Wall time: 12.1 s

# %%
# %%time
NN_(X_train, y_train, X_test, y_test)
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 2.38 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.5298037974384162
# 2 of KFold 5
# ROC AUC score: 0.5265748939060111
# 3 of KFold 5
# ROC AUC score: 0.5306451169721487
# 4 of KFold 5
# ROC AUC score: 0.5269856255036446
# 5 of KFold 5
# ROC AUC score: 0.5319512964291641
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.529192146049877
# Std deviation: 0.002088870242169453
#
# TEST SET:
# F1-Score(micro): 0.8274046104928457
# F1-Score(macro): 0.5096046712414036
# F1-Score(weighted): 0.7732851310210613
# F1-Score(None): [0.90438006 0.11482928]
# Accuracy: 0.8274046104928457
# Sensitivity: 0.06742469579094355
# Specificity: 0.9787124190793915
# Confusion Matrix: [0.9787124190793915, 0.07]
# ROC AUC score: 0.5230685574351674
# CPU times: user 12min 1s, sys: 7min 11s, total: 19min 12s
# Wall time: 2min 25s

# %% [markdown]
# ## Undersampling
# ### Error to execute

# %%
print("Resampling dataset using Random UnderSampling (RUS)...")
X_RUS, y_RUS = RandomUnderSampler(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y RUS:", len(X_RUS), len(y_RUS))
# Out:
# Resampling dataset using Random UnderSampling (RUS)...
# ... DONE!
# X and Y RUS: 22566 22566

# %%
# %%time
LogisticRegr_(X_RUS, y_RUS, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-5a0b413602ac> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'LogisticRegr_(X_RUS, y_RUS, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-67a89159c438> in LogisticRegr_(Xtrain, Ytrain, Xtest, Ytest)
#      11         #model
#      12         lr = LogisticRegression(solver='lbfgs', random_state=42, class_weight='balanced')
# ---> 13         lr.fit(xtr_LR, ytr_LR.values.ravel())
#      14         score = roc_auc_score(yvl_LR, lr.predict(xvl_LR))
#      15         print('ROC AUC score:',score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1561             raise ValueError("This solver needs samples of at least 2 classes"
#    1562                              " in the data, but the data contains only one"
# -> 1563                              " class: %r" % classes_[0])
#    1564
#    1565         if len(self.classes_) == 2:
#
# ValueError: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0

# %%
# %%time
DecisionTree_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 3.58 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-754dad334deb> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'DecisionTree_(X_RUS, y_RUS, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-015e400053b2> in DecisionTree_(Xtrain, Ytrain, Xtest, Ytest)
#      13         dt = DecisionTreeClassifier(random_state=42, class_weight='balanced')
#      14         dt.fit(xtr_DT, ytr_DT.values.ravel())
# ---> 15         score = roc_auc_score(yvl_DT, dt.predict(xvl_DT))
#      16         print('ROC AUC score:',score)
#      17         cv_score.append(score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      74
#      75     if y_type == "binary":
# ---> 76         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77
#      78     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     321     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     322         if len(np.unique(y_true)) != 2:
# --> 323             raise ValueError("Only one class present in y_true. ROC AUC score "
#     324                              "is not defined in that case.")
#     325
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# %%time
RandomForest_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.38 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-5c8ea5c6f008> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'RandomForest_(X_RUS, y_RUS, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-2d63457d1bac> in RandomForest_(Xtrain, Ytrain, Xtest, Ytest)
#      13         rf = RandomForestClassifier(random_state=42, class_weight='balanced', n_estimators=100)
#      14         rf.fit(xtr_RF, ytr_RF.values.ravel())
# ---> 15         score = roc_auc_score(yvl_RF, rf.predict(xvl_RF))
#      16         print('ROC AUC score:',score)
#      17         cv_score.append(score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      74
#      75     if y_type == "binary":
# ---> 76         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77
#      78     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     321     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     322         if len(np.unique(y_true)) != 2:
# --> 323             raise ValueError("Only one class present in y_true. ROC AUC score "
#     324                              "is not defined in that case.")
#     325
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# %%time
NN_(X_RUS, y_RUS, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.38 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-20af7b7d0a47> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'NN_(X_RUS, y_RUS, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-c64caad24ca0> in NN_(Xtrain, Ytrain, Xtest, Ytest)
#      14         nn = MLPClassifier(random_state=42)
#      15         nn.fit(xtr_NN, ytr_NN.values.ravel())
# ---> 16         score = roc_auc_score(yvl_NN, nn.predict(xvl_NN))
#      17         print('ROC AUC score:',score)
#      18         cv_score.append(score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      74
#      75     if y_type == "binary":
# ---> 76         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77
#      78     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     321     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     322         if len(np.unique(y_true)) != 2:
# --> 323             raise ValueError("Only one class present in y_true. ROC AUC score "
#     324                              "is not defined in that case.")
#     325
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
print("Resampling dataset using Edited Nearest Neighbour (ENN)...")
X_ENN, y_ENN = EditedNearestNeighbours(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y ENN:", len(X_ENN), len(y_ENN))
# Out:
# Resampling dataset using Edited Nearest Neighbour (ENN)...
# ... DONE!
# X and Y ENN: 58956 58956

# %%
# %%time
LogisticRegr_(X_ENN, y_ENN, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-ba785ba80b9f> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'LogisticRegr_(X_ENN, y_ENN, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-67a89159c438> in LogisticRegr_(Xtrain, Ytrain, Xtest, Ytest)
#      12         lr = LogisticRegression(solver='lbfgs', random_state=42, class_weight='balanced')
#      13         lr.fit(xtr_LR, ytr_LR.values.ravel())
# ---> 14         score = roc_auc_score(yvl_LR, lr.predict(xvl_LR))
#      15         print('ROC AUC score:',score)
#      16         cv_score.append(score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      74
#      75     if y_type == "binary":
# ---> 76         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77
#      78     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     321     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     322         if len(np.unique(y_true)) != 2:
# --> 323             raise ValueError("Only one class present in y_true. ROC AUC score "
#     324                              "is not defined in that case.")
#     325
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# %%time
DecisionTree_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.86 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-4fb5aeb01eb6> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'DecisionTree_(X_ENN, y_ENN, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-015e400053b2> in DecisionTree_(Xtrain, Ytrain, Xtest, Ytest)
#      13         dt = DecisionTreeClassifier(random_state=42, class_weight='balanced')
#      14         dt.fit(xtr_DT, ytr_DT.values.ravel())
# ---> 15         score = roc_auc_score(yvl_DT, dt.predict(xvl_DT))
#      16         print('ROC AUC score:',score)
#      17         cv_score.append(score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      74
#      75     if y_type == "binary":
# ---> 76         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77
#      78     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     321     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     322         if len(np.unique(y_true)) != 2:
# --> 323             raise ValueError("Only one class present in y_true. ROC AUC score "
#     324                              "is not defined in that case.")
#     325
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# %%time
RandomForest_(X_ENN, y_ENN, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.62 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-4a1ddde876be> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'RandomForest_(X_ENN, y_ENN, X_test, y_test)')
#
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# </usr/local/lib/python3.6/dist-packages/decorator.py:decorator-gen-60> in time(self, line, cell, local_ns)
#
# /usr/lib/python3/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/lib/python3/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1187         if mode=='eval':
#    1188             st = clock2()
# -> 1189             out = eval(code, glob, local_ns)
#    1190             end = clock2()
#    1191         else:
#
# <timed eval> in <module>()
#
# <ipython-input-1-2d63457d1bac> in RandomForest_(Xtrain, Ytrain, Xtest, Ytest)
#      13         rf = RandomForestClassifier(random_state=42, class_weight='balanced', n_estimators=100)
#      14         rf.fit(xtr_RF, ytr_RF.values.ravel())
# ---> 15         score = roc_auc_score(yvl_RF, rf.predict(xvl_RF))
#      16         print('ROC AUC score:',score)
#      17         cv_score.append(score)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr)
#     353     return _average_binary_score(
#     354         _binary_roc_auc_score, y_true, y_score, average,
# --> 355         sample_weight=sample_weight)
#     356
#     357
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      74
#      75     if y_type == "binary":
# ---> 76         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77
#      78     check_consistent_length(y_true, y_score, sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/ranking.py in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     321     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     322         if len(np.unique(y_true)) != 2:
# --> 323             raise ValueError("Only one class present in y_true. ROC AUC score "
#     324                              "is not defined in that case.")
#     325
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
# %%time
NN_(X_ENN, y_ENN, X_test, y_test)

# %%
print("Resampling dataset using Tomek's Link (TL)...")
X_TL, y_TL = TomekLinks(random_state=42).fit_sample(X_train, y_train.values.ravel())
print("... DONE!")
print("X and Y TL:", len(X_TL), len(y_TL))
# Out:
# Resampling dataset using Tomek's Link (TL)...
# ... DONE!
# X and Y TL: 67332 67332

# %%
# %%time
LogisticRegr_(X_TL, y_TL, X_test, y_test)
# Out:
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.5919706909783181
# 2 of KFold 5
# ROC AUC score: 0.5877359049870421
# 3 of KFold 5
# ROC AUC score: 0.5894844545485806
# 4 of KFold 5
# ROC AUC score: 0.5853049613756715
# 5 of KFold 5
# ROC AUC score: 0.5841130860523047
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5877218195883833
# Std deviation: 0.002829280821846517
#
# TEST SET:
# F1-Score(micro): 0.7243309485956546
# F1-Score(macro): 0.5685753667040047
# F1-Score(weighted): 0.7417172587952352
# F1-Score(None): [0.82779881 0.30935192]
# Accuracy: 0.7243309485956545
# Sensitivity: 0.3718332335926591
# Specificity: 0.7945112990984551
# Confusion Matrix: [0.7945112990984551, 0.37]
# ROC AUC score: 0.5831722663455571
# CPU times: user 3.97 s, sys: 2.34 s, total: 6.31 s
# Wall time: 822 ms

# %%
# %%time
DecisionTree_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 5 µs, sys: 3 µs, total: 8 µs
# Wall time: 15 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6400600794465865
# 2 of KFold 5
# ROC AUC score: 0.639089509216445
# 3 of KFold 5
# ROC AUC score: 0.6480921877698761
# 4 of KFold 5
# ROC AUC score: 0.6390604339463878
# 5 of KFold 5
# ROC AUC score: 0.6532921359102899
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.6439188692579171
# Std deviation: 0.005780866475421388
#
# TEST SET:
# F1-Score(micro): 0.6223834128245893
# F1-Score(macro): 0.5123634951126834
# F1-Score(weighted): 0.6670710929495354
# F1-Score(None): [0.7439876  0.28073939]
# Accuracy: 0.6223834128245893
# Sensitivity: 0.4438460003989627
# Specificity: 0.6579292267365662
# Confusion Matrix: [0.6579292267365662, 0.44]
# ROC AUC score: 0.5508876135677645
# CPU times: user 684 ms, sys: 190 µs, total: 684 ms
# Wall time: 676 ms

# %%
# %%time
RandomForest_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 2.62 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6244729120858714
# 2 of KFold 5
# ROC AUC score: 0.6193293972523584
# 3 of KFold 5
# ROC AUC score: 0.6318155588501152
# 4 of KFold 5
# ROC AUC score: 0.6266004501426665
# 5 of KFold 5
# ROC AUC score: 0.630436222570642
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.6265309081803306
# Std deviation: 0.004456028654393208
#
# TEST SET:
# F1-Score(micro): 0.7580816110227874
# F1-Score(macro): 0.5421599588229085
# F1-Score(weighted): 0.7521665199429413
# F1-Score(None): [0.85657621 0.22774371]
# Accuracy: 0.7580816110227875
# Sensitivity: 0.21484141232794735
# Specificity: 0.8662377377973708
# Confusion Matrix: [0.8662377377973708, 0.21]
# ROC AUC score: 0.540539575062659
# CPU times: user 12.1 s, sys: 28.4 ms, total: 12.1 s
# Wall time: 12.1 s

# %%
# %%time
NN_(X_TL, y_TL, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.38 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.5296196220298814
# 2 of KFold 5
# ROC AUC score: 0.5251477710143129
# 3 of KFold 5
# ROC AUC score: 0.5305121305625833
# 4 of KFold 5
# ROC AUC score: 0.5242791548832413
# 5 of KFold 5
# ROC AUC score: 0.525967034943425
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5271051426866887
# Std deviation: 0.0024917051558386834
#
# TEST SET:
# F1-Score(micro): 0.8287957074721781
# F1-Score(macro): 0.5009627038210894
# F1-Score(weighted): 0.7711224991554793
# F1-Score(None): [0.90543878 0.09648663]
# Accuracy: 0.828795707472178
# Sensitivity: 0.05505685218432076
# Specificity: 0.9828428452281663
# Confusion Matrix: [0.9828428452281663, 0.06]
# ROC AUC score: 0.5189498487062435
# CPU times: user 11min 16s, sys: 6min 47s, total: 18min 3s
# Wall time: 2min 15s

# %% [markdown]
# ## Oversampling

# %%
print("Resampling dataset using Random OverSampling (ROS)...")
ros = RandomOverSampler(random_state=42)
X_ROS, y_ROS = ros.fit_resample(X_train, y_train)
print("X and Y ROS:", len(X_ROS), len(y_ROS))
# Out:
# Resampling dataset using Random OverSampling (ROS)...
# X and Y ROS: 112392 112392
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# %%time
LogisticRegr_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 1 µs, sys: 1e+03 ns, total: 2 µs
# Wall time: 3.34 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.589279359430605
# 2 of KFold 5
# ROC AUC score: 0.5881306166029006
# 3 of KFold 5
# ROC AUC score: 0.5879081768840644
# 4 of KFold 5
# ROC AUC score: 0.5873743215588576
# 5 of KFold 5
# ROC AUC score: 0.586929442121185
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5879243833195225
# Std deviation: 0.0007963957566464705
#
# TEST SET:
# F1-Score(micro): 0.7277755696873345
# F1-Score(macro): 0.5703124632175095
# F1-Score(weighted): 0.744050002478356
# F1-Score(None): [0.8304277  0.31019723]
# Accuracy: 0.7277755696873344
# Sensitivity: 0.3686415320167564
# Specificity: 0.7992771754239644
# Confusion Matrix: [0.7992771754239644, 0.37]
# ROC AUC score: 0.5839593537203605
# CPU times: user 8.13 s, sys: 5.17 s, total: 13.3 s
# Wall time: 1.69 s

# %%
# %%time
DecisionTree_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 9 µs, sys: 5 µs, total: 14 µs
# Wall time: 3.81 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.7900800711743772
# 2 of KFold 5
# ROC AUC score: 0.7924192543820625
# 3 of KFold 5
# ROC AUC score: 0.7908621763502091
# 4 of KFold 5
# ROC AUC score: 0.7908621763502091
# 5 of KFold 5
# ROC AUC score: 0.7910846160690453
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7910616588651805
# Std deviation: 0.0007598280809449851
#
# TEST SET:
# F1-Score(micro): 0.6357644409114998
# F1-Score(macro): 0.5202916866011499
# F1-Score(weighted): 0.6774930342972624
# F1-Score(None): [0.75564937 0.284934  ]
# Accuracy: 0.6357644409114998
# Sensitivity: 0.43706363455016956
# Specificity: 0.6753246753246753
# Confusion Matrix: [0.6753246753246753, 0.44]
# ROC AUC score: 0.5561941549374224
# CPU times: user 1.02 s, sys: 11.7 ms, total: 1.03 s
# Wall time: 1.01 s

# %%
# %%time
RandomForest_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.86 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.7921263345195729
# 2 of KFold 5
# ROC AUC score: 0.7954444345582348
# 3 of KFold 5
# ROC AUC score: 0.7945991636266572
# 4 of KFold 5
# ROC AUC score: 0.7929086217635021
# 5 of KFold 5
# ROC AUC score: 0.7928641338197349
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7935885376575404
# Std deviation: 0.0012321365764667018
#
# TEST SET:
# F1-Score(micro): 0.6959790673025967
# F1-Score(macro): 0.5434539007524377
# F1-Score(weighted): 0.7197087004000514
# F1-Score(None): [0.80733791 0.27956989]
# Accuracy: 0.6959790673025967
# Sensitivity: 0.35527628166766406
# Specificity: 0.7638111124349657
# Confusion Matrix: [0.7638111124349657, 0.36]
# ROC AUC score: 0.5595436970513148
# CPU times: user 20.5 s, sys: 8.61 ms, total: 20.5 s
# Wall time: 20.5 s

# %%
# %%time
NN_NoIloc(X_ROS, y_ROS, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.38 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6024911032028468
# 2 of KFold 5
# ROC AUC score: 0.6034789572025981
# 3 of KFold 5
# ROC AUC score: 0.5980069401192276
# 4 of KFold 5
# ROC AUC score: 0.5923569712607883
# 5 of KFold 5
# ROC AUC score: 0.6029895898211585
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5998647123213239
# Std deviation: 0.0042318565169502
#
# TEST SET:
# F1-Score(micro): 0.5517355590885002
# F1-Score(macro): 0.4952754963065995
# F1-Score(weighted): 0.6080278854985001
# F1-Score(None): [0.66408538 0.32646561]
# Accuracy: 0.5517355590885002
# Sensitivity: 0.6542988230600438
# Specificity: 0.5313157790222011
# Confusion Matrix: [0.5313157790222011, 0.65]
# ROC AUC score: 0.5928073010411224
# CPU times: user 20min 29s, sys: 12min 16s, total: 32min 45s
# Wall time: 4min 8s

# %%
print("Resampling dataset using SMOTE (SMO)...")
sm = SMOTE(random_state=42)
X_SMO, y_SMO = sm.fit_resample(X_train, y_train)
print("X and Y SMO:", len(X_SMO), len(y_SMO))
# Out:
# Resampling dataset using SMOTE (SMO)...
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# X and Y SMO: 112392 112392

# %%
# %%time
LogisticRegr_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.86 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.5873220640569395
# 2 of KFold 5
# ROC AUC score: 0.5811904973752113
# 3 of KFold 5
# ROC AUC score: 0.5867070024023489
# 4 of KFold 5
# ROC AUC score: 0.5804342023311683
# 5 of KFold 5
# ROC AUC score: 0.5855058279206335
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5842319188172602
# Std deviation: 0.002862543472369799
#
# TEST SET:
# F1-Score(micro): 0.7226086380498145
# F1-Score(macro): 0.5685600046299546
# F1-Score(weighted): 0.7407536048486174
# F1-Score(None): [0.82636369 0.31075632]
# Accuracy: 0.7226086380498146
# Sensitivity: 0.37662078595651305
# Specificity: 0.7914929107589658
# Confusion Matrix: [0.7914929107589658, 0.38]
# ROC AUC score: 0.5840568483577394
# CPU times: user 8.7 s, sys: 4.72 s, total: 13.4 s
# Wall time: 1.71 s

# %%
# %%time
DecisionTree_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 8 µs, sys: 5 µs, total: 13 µs
# Wall time: 3.81 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6701957295373666
# 2 of KFold 5
# ROC AUC score: 0.8445146365334995
# 3 of KFold 5
# ROC AUC score: 0.8446925883085684
# 4 of KFold 5
# ROC AUC score: 0.8422457514013703
# 5 of KFold 5
# ROC AUC score: 0.8412225286947238
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.8085742468951057
# Std deviation: 0.0692019375164132
#
# TEST SET:
# F1-Score(micro): 0.35506094329623744
# F1-Score(macro): 0.35026479528991783
# F1-Score(weighted): 0.3875505010321852
# F1-Score(None): [0.40608796 0.29444163]
# Accuracy: 0.35506094329623744
# Sensitivity: 0.81049271893078
# Specificity: 0.26438698915763137
# Confusion Matrix: [0.26438698915763137, 0.81]
# ROC AUC score: 0.5374398540442057
# CPU times: user 1.68 s, sys: 7.51 ms, total: 1.69 s
# Wall time: 1.67 s

# %%
# %%time
RandomForest_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 2.62 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6983540925266903
# 2 of KFold 5
# ROC AUC score: 0.8523445146365334
# 3 of KFold 5
# ROC AUC score: 0.849274846516594
# 4 of KFold 5
# ROC AUC score: 0.8463386422279562
# 5 of KFold 5
# ROC AUC score: 0.8465165940030251
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.8185657379821597
# Std deviation: 0.0601456222262311
#
# TEST SET:
# F1-Score(micro): 0.2574523052464229
# F1-Score(macro): 0.2546447365231276
# F1-Score(weighted): 0.22409026762190076
# F1-Score(None): [0.2088994  0.30039008]
# Accuracy: 0.2574523052464229
# Sensitivity: 0.9601037303012169
# Specificity: 0.11755828269589738
# Confusion Matrix: [0.11755828269589738, 0.96]
# ROC AUC score: 0.5388310064985572
# CPU times: user 27.1 s, sys: 41.7 ms, total: 27.1 s
# Wall time: 27.1 s

# %%
# %%time
NN_NoIloc(X_SMO, y_SMO, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 0 ns, total: 1e+03 ns
# Wall time: 2.62 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6008896797153025
# 2 of KFold 5
# ROC AUC score: 0.6054809146721238
# 3 of KFold 5
# ROC AUC score: 0.6087285345671323
# 4 of KFold 5
# ROC AUC score: 0.5999644096449862
# 5 of KFold 5
# ROC AUC score: 0.6070824806477444
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.6044292038494579
# Std deviation: 0.0034378143180610883
#
# TEST SET:
# F1-Score(micro): 0.62629173290938
# F1-Score(macro): 0.5307574815670772
# F1-Score(weighted): 0.6721759439152296
# F1-Score(None): [0.74248545 0.31902951]
# Accuracy: 0.62629173290938
# Sensitivity: 0.5272292040694195
# Specificity: 0.6460145359227928
# Confusion Matrix: [0.6460145359227928, 0.53]
# ROC AUC score: 0.5866218699961061
# CPU times: user 37min 50s, sys: 22min 42s, total: 1h 33s
# Wall time: 7min 39s

# %%
print("Resampling dataset using ADASYN (ADA)...")
ada = ADASYN(random_state=42)
X_ADA, y_ADA = ada.fit_resample(X_train, y_train)
print("X and Y ADA:", len(X_ADA), len(y_ADA))
# Out:
# Resampling dataset using ADASYN (ADA)...
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# X and Y ADA: 111480 111480

# %%
# %%time
LogisticRegr_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 1e+03 ns, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.62 µs
#
# LOGISTIC REGRESSION
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.579440400551397
# 2 of KFold 5
# ROC AUC score: 0.5412396117110615
# 3 of KFold 5
# ROC AUC score: 0.5398141708372287
# 4 of KFold 5
# ROC AUC score: 0.5288181529286526
# 5 of KFold 5
# ROC AUC score: 0.53174863838564
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.544212194882796
# Std deviation: 0.01822921890313046
#
# TEST SET:
# F1-Score(micro): 0.6904809220985691
# F1-Score(macro): 0.5541104142977229
# F1-Score(weighted): 0.7188135142744771
# F1-Score(None): [0.80069952 0.3075213 ]
# Accuracy: 0.6904809220985691
# Sensitivity: 0.41392379812487534
# Specificity: 0.7455419198538464
# Confusion Matrix: [0.7455419198538464, 0.41]
# ROC AUC score: 0.5797328589893609
# CPU times: user 7.36 s, sys: 4.19 s, total: 11.6 s
# Wall time: 1.48 s

# %%
# %%time
DecisionTree_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 7 µs, sys: 4 µs, total: 11 µs
# Wall time: 3.81 µs
#
# DECISION TREE
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6759330211260511
# 2 of KFold 5
# ROC AUC score: 0.8093247373897642
# 3 of KFold 5
# ROC AUC score: 0.7991077151654351
# 4 of KFold 5
# ROC AUC score: 0.8053946015431301
# 5 of KFold 5
# ROC AUC score: 0.7994683199807266
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7778456790410214
# Std deviation: 0.051099269799494765
#
# TEST SET:
# F1-Score(micro): 0.32641096979332274
# F1-Score(macro): 0.3253857318225185
# F1-Score(weighted): 0.3429515337929844
# F1-Score(None): [0.35168478 0.29908668]
# Accuracy: 0.32641096979332274
# Sensitivity: 0.8655495711151008
# Specificity: 0.21907144842924658
# Confusion Matrix: [0.21907144842924658, 0.87]
# ROC AUC score: 0.5423105097721737
# CPU times: user 1.7 s, sys: 5.52 ms, total: 1.7 s
# Wall time: 1.69 s

# %%
# %%time
RandomForest_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 1 µs, sys: 0 ns, total: 1 µs
# Wall time: 2.62 µs
# RANDOM FOREST
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.6848031206459443
# 2 of KFold 5
# ROC AUC score: 0.8124597674203936
# 3 of KFold 5
# ROC AUC score: 0.8112320498469686
# 4 of KFold 5
# ROC AUC score: 0.8072458906550316
# 5 of KFold 5
# ROC AUC score: 0.8074287164397695
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.7846339090016216
# Std deviation: 0.049957643573977535
#
# TEST SET:
# F1-Score(micro): 0.25520005299417065
# F1-Score(macro): 0.25194043269664
# F1-Score(weighted): 0.21895824357471225
# F1-Score(None): [0.20256037 0.30132049]
# Accuracy: 0.25520005299417065
# Sensitivity: 0.9672850588469978
# Specificity: 0.1134278565471226
# Confusion Matrix: [0.1134278565471226, 0.97]
# ROC AUC score: 0.5403564576970602
# CPU times: user 26.9 s, sys: 34.5 ms, total: 26.9 s
# Wall time: 26.9 s

# %%
# %%time
NN_NoIloc(X_ADA, y_ADA, X_test, y_test)
# Out:
# CPU times: user 1 µs, sys: 1e+03 ns, total: 2 µs
# Wall time: 2.62 µs
# NEURAL NETWORK
# TRAIN AND VALIDATION SETS:
# 1 of KFold 5
# ROC AUC score: 0.5966204401198963
# 2 of KFold 5
# ROC AUC score: 0.577528584761217
# 3 of KFold 5
# ROC AUC score: 0.5747748908838325
# 4 of KFold 5
# ROC AUC score: 0.5691093470203897
# 5 of KFold 5
# ROC AUC score: 0.5721994863541763
#
# CROSS VALIDANTION SUMMARY:
# Mean: 0.5780465498279025
# Std deviation: 0.009695598856430069
#
# TEST SET:
# F1-Score(micro): 0.6280471648118707
# F1-Score(macro): 0.5326633145881224
# F1-Score(weighted): 0.6736831623602711
# F1-Score(None): [0.74379449 0.32153214]
# Accuracy: 0.6280471648118707
# Sensitivity: 0.53081986834231
# Specificity: 0.6474045831843998
# Confusion Matrix: [0.6474045831843998, 0.53]
# ROC AUC score: 0.5891122257633549
# CPU times: user 31min 6s, sys: 18min 52s, total: 49min 58s
# Wall time: 6min 24s
